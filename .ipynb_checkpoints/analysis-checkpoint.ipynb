# %%
import pandas as pd
import numpy as np
import scipy as sp

import sklearn

import re
import pickle

import sys
import warnings

import nltk
import gensim.corpora

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from gensim.models import ldamodel,LsiModel
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.decomposition import NMF
from sklearn.preprocessing import normalize

warnings.filterwarnings('ignore')
#nltk.download('stopwords')
#nltk.download('wordnet')

# %% [markdown]
# ## Exploration

# %%
filename = 'data/raw_da_qs.csv'

# %%
data_total = pd.read_csv(filename)

list(data_total.columns)
# Out:
# ['year', 'month', 'day', 'url', 'title', 'letterId', 'question_only']

# %%
def group_textOfSameTitle(df=data_total):
    res = df.groupby(["title"])['year', 'month', 'day', 'url','letterId', 'question_only']\
            .agg(lambda x: ','.join(x.astype(str)))\
            .sort_values('year')\
            .reset_index()
    return res

# %%
data_total = group_textOfSameTitle()

data_titles = data_total[['title']]

display(data_titles.head(8))
# Out:
#                                                title
# 0  A POINTED REMINDER ABOUT HOW CROWDED IT'S GETTING
# 1    AMERICAN SMOKEOUT DAY CHANCE TO SNUFF OUT HABIT
# 2  HOW DID 'PEGGY' BECOME A NICKNAME FOR 'MARGARET'?
# 3  HUSBAND CAN'T STOMACH WIFE'S VOW TO DONATE ORGANS
# 4                        LATE ANSWER FOR EARLY GUEST
# 5                  BLOOD BANKS SAVE LIVES, NOT BLOOD
# 6             TALK OF LONG WALKS WEARS THIN WITH AGE
# 7    HOLY COW! SOME READERS TAKE A BULL BY THE HORNS

# %%
data_titles = data_titles.astype('str')
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}', '#', '...', 
                   '--', "'s", 'also', '&', '-', '–', '=', 'known', 'mi', 'km', '$'])

for idx in range(len(data_titles)):
    data_titles.iloc[idx]['title'] = [lemmatizer.lemmatize(word) for word in data_titles.iloc[idx]['title'].split(' ') if word not in stopwords.words()] #remove stopwords

pickle.dump(data_titles,
            open('data_questions.data', 
                 'wb')
            )

#tokenization
titles = [val[0] for val in data_titles.iloc[0:].values]

# %%
[val[0] for val in data_titles.iloc[0:].values]
# Out:
# [['A', 'POINTED', 'REMINDER', 'ABOUT', 'HOW', 'CROWDED', "IT'S", 'GETTING'],
#  ['AMERICAN', 'SMOKEOUT', 'DAY', 'CHANCE', 'TO', 'SNUFF', 'OUT', 'HABIT'],
#  ['HOW', 'DID', "'PEGGY'", 'BECOME', 'A', 'NICKNAME', 'FOR', "'MARGARET'?"],
#  ['HUSBAND', "CAN'T", 'STOMACH', "WIFE'S", 'VOW', 'TO', 'DONATE', 'ORGANS'],
#  ['LATE', 'ANSWER', 'FOR', 'EARLY', 'GUEST'],
#  ['BLOOD', 'BANKS', 'SAVE', 'LIVES,', 'NOT', 'BLOOD'],
#  ['TALK', 'OF', 'LONG', 'WALKS', 'WEARS', 'THIN', 'WITH', 'AGE'],
#  ['HOLY',
#   'COW!',
#   'SOME',
#   'READERS',
#   'TAKE',
#   'A',
#   'BULL',
#   'BY',
#   'THE',
#   'HORNS'],
#  ['UNTANGLING', 'THE', 'GNARLED', 'ROOTS', 'OF', 'THE', 'WORD', "'OK'"],
#  ['SNOW', 'JOBS', 'DESERVE', 'A', 'CHILLY', 'RECEPTION'],
#  ['Dear', 'Abby:', 'Mock', 'Raid', 'Camp', 'Misses', 'Point'],
#  ['READERS', 'ADD', 'TIDBITS', 'ABOUT', "'LET", 'THEM', 'EAT', "CAKE'"],
#  ['TEEN-ABUSING', 'FATHER', 'NEEDS', 'HELP'],
#  ['TEENAGER', 'FEELS', 'GUILTY', 'ABOUT', 'LYING', 'TO', 'THE', 'HOSPITAL'],
#  ['YOUR', 'LIVING', 'WILL', 'MAY', 'EXPIRE', 'BEFORE', 'YOU', 'DO'],
#  ['An', 'Alternative', "'Throw", 'Bum', 'Out!‘'],
#  ['READERS', 'DIFFER', 'ON', 'CONFESSIONS', 'OF', "'MISSING", "LINK'"],
#  ['BOSOM', 'BUDDY', 'RECALLS', 'WHEN'],
#  ['HARNESS', 'VIEWS', 'UNLEASHED'],
#  ['Good', 'Help', 'Is', 'So', 'Hard', 'Get', 'N', 'owadays'],
#  ['EX-FLAME-TURNED', 'PRIEST', 'CALLS', 'FOR', 'CHANGE', 'OF', 'PARISH'],
#  ['NO', 'ROSES', 'FROM', 'SPOUSE?', 'BUY', 'THEM,', 'THEN', 'BILL', 'HIM'],
#  ['Protest', 'Registered', 'Checkout', 'Counter'],
#  ['MOTHER-IN-LAW', "ISN'T", 'BUYING', "SUPERMARKET'S", 'REGISTER', 'RULES'],
#  ['NO', 'HATS', 'INDOORS,', 'AND', 'THAT', 'MEANS', 'YOU,', 'TOO,', 'TEX'],
#  ['SOME', 'READER', 'SUGGESTIONS', 'TO', 'AID', 'ORGAN', 'DONATIONS'],
#  ['ELDERLY',
#   "LOVER'S",
#   'GENEROSITY',
#   'IN',
#   'WILL',
#   'MAY',
#   'LEAVE',
#   'LEGACY',
#   'OF',
#   'BITTERNESS',
#   'FOR',
#   'LIVING'],
#  ['VICTIM',
#   'WANTS',
#   'TO',
#   'HELP',
#   'TEENAGE',
#   'THIEF,',
#   'NOT',
#   'PUNISH',
#   'HER'],
#  ['LETTERS', 'KEEP', 'POURING', 'IN', 'TO', 'ONCE-LONELY', 'MARINES'],
#  ['HAIR', 'OR', 'BARE:', 'BEAUTIFUL', 'OR', 'BEASTLY?'],
#  ["'TAKING",
#   'CARE',
#   'OF',
#   'TROPICAL',
#   'FISH',
#   'IS',
#   'LIKE',
#   'TAKING',
#   'CARE',
#   'OF',
#   "CHILDREN'",
#   'TALES',
#   'OF',
#   'THE',
#   'DEEP',
#   'FROM',
#   'A',
#   'SENIOR',
#   'AQUARIST',
#   'AT',
#   'SHEDD',
#   'AQUARIUM'],
#  ['LETTERS', 'COLUMNS', 'OPEN', 'TINY', 'WINDOW', 'INTO', 'SOVIET', 'LIFE'],
#  ["LET'S", 'NOT', 'CLOUD', 'PRIVACY', 'ISSUE'],
#  ['AN', 'UNUSUAL', "'VASECTOMY'"],
#  ['LAMENT', 'ABOUT', 'OLD', 'AGE', 'AND', 'SICKNESS', 'IS', 'ILL-ADVISED'],
#  ['READERS', 'SEE', 'LIGHT', 'SIDE', 'TO', 'FORM', 'THANK-YOU', 'NOTE'],
#  ['Her', 'Brother', 'Gave', 'Another', 'Gift', 'Sight'],
#  ['ABBY', 'TAKES', 'RAP', 'FOR', 'REMARK', 'ABOUT', 'EASTER', 'EGGS'],
#  ['TV', 'WILL', 'SHOW', 'HOMOSEXUALS', 'IN', 'A', 'NEW', 'WAY'],
#  ['Dear', 'Abby:', "Father's", 'Day', 'Founder', 'Is', 'Remembered'],
#  ['IS',
#   'FAMILY',
#   'READY',
#   'FOR',
#   'STORY',
#   'OF',
#   "GRANDMA'S",
#   'VIVID',
#   'LIFE?'],
#  ['A', 'Great', 'American', 'Smokeout', 'Encourage', 'Quitters'],
#  ["IT'S", 'UP', 'TO', 'NEIGHBORS', 'TO', 'TAME', "CATS'", 'WILD', 'WAYS'],
#  ['TRAGEDY',
#   'SPARKS',
#   'A',
#   'LESSON:',
#   '2',
#   'GUILTY',
#   'IN',
#   "GOSSIP'S",
#   'PAIN'],
#  ['Dear', 'Abby:', 'Goodby', 'Pal,', 'Another', 'Fast', 'Driver'],
#  ['Dear', 'Abby:', 'Suicide', 'Attempts', 'Are', 'Rarely', 'Talked', 'About'],
#  ['Dear', 'Abby:', 'Some', 'Teen-Agers', 'Who', 'Made', 'Her', 'Day'],
#  ["DON'T", 'FRIGHTEN', 'MOTHERS-TO-BE'],
#  ['RESTRICTIONS', 'ARE', 'FOR', 'BLOOD', "DONORS'", 'SAFETY'],
#  ['Dear', 'Abby:', 'Resolutions', 'Just', 'T0day--and', 'All', 'Year'],
#  ['Dear', 'Abby:', 'I', 'cannot', 'work', 'I', 'react'],
#  ['Though', 'You', "Can't", 'See', 'Him,', 'Santa', 'Lives'],
#  ['SIBLINGS', 'FINALLY', 'TOGETHER', 'WITH', 'SALVATION', 'ARMY', 'HELP'],
#  ['TO',
#   'SMOKE',
#   'OR',
#   'NOT',
#   'TO',
#   'SMOKE:',
#   'MORE',
#   'COMMENT',
#   'ON',
#   'THE',
#   'ISSUE'],
#  ['TIP', 'OFF', 'THE', 'OLD', 'TIGHTWAD'],
#  ['ADVICE', 'TO', 'THE', 'YOUNG:', 'READ,', 'READ,', 'READ'],
#  ['BLOCK', 'PARTIES', 'CAN', 'BE', 'A', 'SAFE', 'TREAT', 'ON', 'HALLOWEEN'],
#  ['A', 'LEGAL', 'VIEW', 'OF', 'CAMP', 'RAID'],
#  ['THANK-YOU', 'NOTES', 'A', "MAN'S", 'JOB'],
#  ['Dear', 'Abby:', 'Unhappy', 'Over', 'Predatory', 'Females'],
#  ['Tricks', 'Have', 'Spoiled', "Halloween's", 'Treats'],
#  ["SISTER'S", 'DEATH', 'EMPHASIZES', "SMOKING'S", 'DANGER'],
#  ['YOU', "CAN'T", 'TELL', 'THE', 'STARS', 'BY', 'THEIR', 'PAY'],
#  ['THE', 'LAST', 'ON', 'THE', 'FIRST', '--', 'CHICKEN', 'OR', 'EGG'],
#  ['READERS',
#   'THROW',
#   'THEIR',
#   'SUGGESTIONS',
#   'ON',
#   'COWBOY',
#   'HATS',
#   'INTO',
#   'THE',
#   'RING'],
#  ['THE',
#   'NIAGARA',
#   'FALLS',
#   'DEBATE',
#   'BRINGS',
#   'A',
#   'TORRENT',
#   'OF',
#   'LETTERS'],
#  ['Simple', 'Solution', 'Alarming', 'Situation'],
#  ['DOES',
#   'ECONOMICS',
#   'OF',
#   'SMOKING',
#   'PUFF',
#   'UP',
#   'U.S.',
#   'WORK',
#   'FORCE?'],
#  ['Dear', 'Abby:', 'Readers', 'Find', 'Fault', 'With', "'OK'", 'Origin'],
#  ['Keeping', 'Her', 'Heart', 'Right', 'Place'],
#  ['NO-FUSS',
#   'DAUGHTER',
#   'DESERVES',
#   'TO',
#   'ENJOY',
#   'LIFE',
#   'ON',
#   'HER',
#   'OWN'],
#  ['NO-SPOUSES', 'CLASS', 'PARTY', 'CALLS', 'FOR', 'GETTING', 'EVEN'],
#  ['NO', 'RETURN', 'POLICY', 'FOR', 'POLITICAL', 'CONTRIBUTIONS'],
#  ['EXPRESSIONS', 'OF', 'SYMPATHY', 'REQUIRE', 'NAME,', 'ADDRESS'],
#  ['What', 'Not', 'Get', 'Your', 'Aunt', 'J', 'ennie'],
#  ['Dear', 'Abby:', 'Marines', '0n', 'Okinawa', 'Say,', "'Please", "Write'"],
#  ["FATHER'S", 'DAY', 'WAS', 'STARTED', 'FOR', 'LOVE,', 'NOT', 'MONEY'],
#  ['For', 'Good', '2nd', 'Marriage,', 'End', 'lst'],
#  ['PAST', 'SEX-CAPADES', 'CALL', 'FOR', 'MATURITY'],
#  ['PASSING', 'UP', 'HITCHHIKER', 'PREVENTS', 'RISK', 'DOWN', 'THE', 'ROAD'],
#  ['Dear', 'Abby:', "'Smoke'", 'Gets', 'Their', 'Ayes'],
#  ["'FLAT-CHESTED'", 'NEEDS', 'MORE', 'SELF-ESTEEM'],
#  ['PARENTS,', 'NOT', 'PEERS,', 'SNUB', 'SEX-WISE', 'BOY'],
#  ["DON'T", 'PENALIZE', 'TRIPLETS', 'WHEN', "IT'S", 'GIFT-GIVING', 'TIME'],
#  ["'GIRLIE'", 'PHOTOS', 'DRAW', 'A', 'REPLY'],
#  ['GAY', 'MAN', 'FINDS', 'WOMEN', "WON'T", 'TAKE', '"NO"', 'FOR', 'ANSWER'],
#  ['GET', 'IN', 'GEAR', 'FOR', 'RIDING', 'LESSONS'],
#  ['STUDENTS', 'AGAINST', 'DRUNK', 'DRIVING', 'GO', 'TO', 'COLLEGE'],
#  ['Dear', 'Abby:', 'Making', 'Memories', 'While', "There's", 'Time'],
#  ["'HAVE",
#   'A',
#   'LITTLE',
#   "DRINK?'",
#   'HELPS',
#   'TEENAGERS',
#   'KNOW',
#   'THEY',
#   'CAN',
#   'JUST',
#   'SAY',
#   'NO',
#   'TO',
#   'ALCOHOL'],
#  ['A', 'Sobering', 'Message', 'From', 'EX-Drunk', 'Driver', 'J', 'ail'],
#  ['FIREFIGHTERS', 'TOO', 'HOT', 'OVER', 'MISSED', 'FEES'],
#  ['CRIME', 'VICTIMS', 'HAVE', 'PLACE', 'TO', 'TURN'],
#  ['FOR', 'MOTHER,', 'A', 'PRAYER', 'IS', 'A', 'SPECIAL', 'TRIBUTE'],
#  ['Costly', 'Fire', 'Tragedies', 'Can', 'Be', 'Prevented'],
#  ["'",
#   'SONA',
#   'ASURES:',
#   'DEAR',
#   'ABBY',
#   'SHE',
#   'GETS',
#   'HER',
#   'KICKS',
#   'IN',
#   'THE',
#   'KITCHEN',
#   'DEAR',
#   'ABBY'],
#  ['PROFANITY', 'AN', 'UNAPPETIZING', 'SIDEDISH'],
#  ['PRIVACY', 'PLEA', '47', 'YEARS', 'LATE'],
#  ["FIANCEE'S", 'INVITING', 'TROUBLE,', 'RUN'],
#  ["'ARSENIC'", 'A', 'TREAT', 'FOR', "'INCREDIBLE", "HULK'"],
#  ['Some', 'Things', 'Consider', 'Give', 'Thanks', 'For'],
#  ['Dear', 'Abby:', 'Milking', 'COW', 'Metaphor', 'Further'],
#  ['COAXING,', 'THERAPY', 'CAN', 'PUT', 'HUSBAND', 'IN', 'TOUCH'],
#  ["DEAF'S", 'ANGUISH', 'IS', 'NO', 'JOKE'],
#  ['Dark', 'View', 'High', 'School', 'Reunion'],
#  ['Dear', 'Abby:', "'Let", 'Them', "Eat'", 'Quote', 'Is', 'Piece', 'Cake'],
#  ['CONCERN', 'ABOUT', 'GIFTS', 'MAY', 'HAVE', 'SOME', 'FOUNDATION'],
#  ['GETTING', 'THE', 'FACTS', 'STRAIGHT', 'ON', 'AIDS'],
#  ['Dear', 'Abby:', "'Smoke'", 'Gets', 'Their', 'Ayes...', 'N', 'ays'],
#  ['SHE', 'WANTS', 'A', 'BABY,', 'BUT', "HE'S", 'ON', 'DRUGS'],
#  ['LETTERS', 'SNUFFS', 'OUT', 'SMOKING'],
#  ["'NORMAL'", 'WIDOW', 'HAS', 'AN', 'EYE', 'FOR', 'THE', 'GUYS'],
#  ["BRIDE'S", 'LITTLE', 'GIFT', 'JOKE', 'IS', 'NO', 'LAUGHING', 'MATTER'],
#  ['BRIDE-TO-BE',
#   'SHOULD',
#   'KEEP',
#   'THE',
#   'MAN',
#   'BUT',
#   'EXCHANGE',
#   'THE',
#   'RING'],
#  ['SPECIAL', "FATHER'S", 'DAY', 'REMEMBRANCE.'],
#  ['Dear', 'Abby:', '16-Year-Old', 'Tired', 'Lying', 'Parents'],
#  ['Nosey', 'Newsie', 'Puts', 'Family', 'Spot'],
#  ['FAMILY',
#   'FEUD',
#   'OVER',
#   'HEIRLOOM',
#   "ISN'T",
#   'WORTH',
#   'PRICE',
#   'OF',
#   'RING'],
#  ['ONE',
#   'REHEARSAL',
#   'BASH',
#   'PER',
#   'SON',
#   'FULFILLS',
#   "PARENTS'",
#   'OBLIGATION'],
#  ['Dear', 'Abby:', 'Blood', 'Donations', 'Unlike', 'Money', 'Banks'],
#  ['SORTING',
#   'THE',
#   'MARCH',
#   'OF',
#   'WIVES,',
#   'SIBLINGS',
#   'A',
#   'HALF',
#   'STEP',
#   'AT',
#   'A',
#   'TIME'],
#  ['OPEN-DOOR', 'POLICY', 'JUST', 'INVITES', 'TROUBLE'],
#  ['WHAT',
#   'TO',
#   'DO',
#   'IF',
#   'YOUR',
#   'LATEST',
#   'GADGET',
#   'HAS',
#   'BECOME',
#   'AN',
#   'ELECTRONIC',
#   'DINOSAUR'],
#  ['FALSE', 'CHARGES', 'HURT', 'CHILDREN,', 'RUIN', 'HARMONY'],
#  ['Dear', 'Abby:', 'AIDS:', 'What', 'It', 'Is', 'HOW', 'Avoid', 'It'],
#  ['Baby', 'Shower', 'Is', 'Only', 'One', 'Several', 'Crises'],
#  ['LOSING', 'A', 'FRIEND', 'COULD', 'SAVE', 'MARRIAGE'],
#  ['Organ', 'Donation', 'Policy', 'Is', 'Clariﬁed'],
#  ['A',
#   "MOM'S",
#   'ADVICE:',
#   "'IT'S",
#   'BETTER',
#   'TO',
#   'BE',
#   'SAFE',
#   'THAN',
#   "SORRY'"],
#  ['WIFE', "CAN'T", 'SHUT', "HUSBAND'S", "'EYES'", 'FOR', 'OTHER', 'WOMEN'],
#  ['NONCYCLING', 'ADULT', 'MASTERS', 'MOTORBIKE'],
#  ['MOCK', 'RAID', 'A', 'BAD', 'LEARNING', 'EXPERIENCE'],
#  ['LIFETIME',
#   'SETS',
#   'OUT',
#   'TO',
#   'BE',
#   'THE',
#   'TALK',
#   'OF',
#   'CABLE',
#   'TELEVISION'],
#  ['NOTHING', 'TO', 'LOSE', 'BUT', '2', 'UNWANTED', 'NEIGHBORS'],
#  ['STD', 'AND', 'THE', 'OLD/NEW', 'MORALITY'],
#  ['WARNINGS', 'OF', 'DISASTER', 'RING', 'TRUE', 'ON', 'THE', 'JOB'],
#  ["SON'S",
#   'REASON',
#   'FOR',
#   'TAKING',
#   'TOWELS',
#   'FROM',
#   'MOTEL',
#   "DOESN'T",
#   'WASH'],
#  ['RUNNER', 'TIRED', 'OF', 'AUTO', 'STUMBLING', 'BLOCKS'],
#  ['MORE',
#   'FOOD',
#   'FOR',
#   'THOUGHT',
#   'ON',
#   'WEDDING',
#   'CAKE',
#   'IN',
#   'THE',
#   'FACE'],
#  ['A', 'WRONG', 'NUMBER', 'ON', 'ADVICE', 'TO', 'PESTERED', 'WOMAN'],
#  ['MOTHER', 'BEARS', 'BURDEN', 'OF', 'A', "DAUGHTER'S", 'SECRET'],
#  ['MOTHER',
#   'AND',
#   'DAUGHTER',
#   'SHARE',
#   'GUILT',
#   'FOR',
#   'CONSTANT',
#   'CRITICISM'],
#  ['A', 'VISIT', 'HOME:', 'HOW', 'LONG', 'IS', 'TOO', 'LONG?'],
#  ['MOOCHERS',
#   'LIKE',
#   'NOTHING',
#   'MORE',
#   'THAN',
#   'JELL-O',
#   'HOST',
#   'AND',
#   'HOSTESS'],
#  ['BENEATH',
#   'THIS',
#   'FORGETFUL',
#   'HUSBAND',
#   'LIES',
#   'A',
#   'THOROUGHLY',
#   'INSENSITIVE',
#   'MAN'],
#  ['A', 'TALL', 'FENCE', 'WILL', 'TREE', 'THAT', 'CATTY', 'NEIGHBOR'],
#  ['MOM', 'SHOULD', 'BE', 'CANDID', 'WITH', 'SEXUALLY', 'ACTIVE', 'SON'],
#  ['Lives', 'Depend', 'Organ', 'Transplants'],
#  ['Dear', 'Abby:', 'Male', 'Nurses', 'Deserve', 'Their', 'Place', 'History'],
#  ['MODEL', 'DAUGHTER', 'WANTS', 'TO', 'BE', 'MOD'],
#  ['MOM', 'WAS', 'WRONG', 'ABOUT', 'ENDING', 'PHONE', 'CALLS'],
#  ['DO', 'RICH', 'RELATIVES', 'MEAN', 'BAD', 'RELATIONS?'],
#  ['DECLARE', 'A', 'TIME', 'LIMIT', 'FOR', 'LAGGING', 'COURTSHIP'],
#  ['MOM',
#   'THINKS',
#   'DAUGHTER',
#   'NEEDS',
#   'MORE',
#   'THAN',
#   'MONEY',
#   'FROM',
#   'DAD'],
#  ['MAKING', 'BOOK', 'ON', 'MEMORIES', 'HITS', 'HOME'],
#  ["DENTIST'S",
#   'WIFE',
#   'SAYS',
#   "HUSBAND'S",
#   'HOURS',
#   "AREN'T",
#   'KID',
#   'STUFF',
#   'TO',
#   'HER'],
#  ['MAYBE', 'YOU', 'HATE', 'IT,', 'BUT', "RELAX--IT'S", 'ONLY', 'A', 'STYLE'],
#  ['DIRECT', 'MAIL', 'BRINGS', 'A', 'SPEEDY', 'REPLY'],
#  ['BIRTHDAY', 'WISH', 'FOR', 'MARCH', 'OF', 'DIMES'],
#  ['TEEN',
#   'SNUGGLE',
#   'ON',
#   'COUCH',
#   'IS',
#   'STEP',
#   '1',
#   'ON',
#   'TEMPTATION',
#   'SCALE'],
#  ['Dear', 'Abby:', 'Indecent', 'Exposure:', 'A', 'Felony', '0f', 'Yore'],
#  ['NIGHTCLUB', 'ACT', 'TURNS', 'HER', 'OFF'],
#  ['NO.', '2', 'WIFE', 'WANTS', 'TO', 'SPILL', 'BEANS', 'TO', 'NO.', '3'],
#  ['Now', 'Hear', 'This:', 'Deafness', "Isn't", 'Funny'],
#  ['OBITUARIES', 'NO', 'PLACE', 'FOR', 'DIRT', 'ABOUT', 'THE', 'DECEASED'],
#  ['OLD', 'SAW', 'RINGS', 'TRUE:', 'ONE', 'WIFE', 'PER', 'MARRIAGE'],
#  ['Pregnant', '16,', 'She', 'Has', 'Caring', 'Mother'],
#  ['Dear', 'Abby:', 'Advice', 'Children', 'Alone', 'Home'],
#  ['AT', 'ANY', 'AGE,', "IT'S", 'IMPORTANT', 'TO', 'HAVE', 'WILL'],
#  ['Dear', 'Abby:', 'A', 'Fowl', 'Reaction', "'Chicken-Egg'", 'Yarn'],
#  ['Dear', 'Abby:', 'A', 'Bitter', 'Memory', 'False', 'Accusation'],
#  ['ATHEIST', 'VOWS', "SHE'LL", 'PUT', 'NEW', 'RELIGION', 'TO', 'PRACTICE'],
#  ['Dear', 'Abby:', 'A', '20-Year', 'Marriage', 'Is', 'Edge'],
#  ['ATTEMPTS', 'AT', 'SUICIDE', 'ARE', 'A', 'CRY', 'FOR', 'HELP'],
#  ['PARTY', 'PEEPER', 'LACKS', 'INTERESTS'],
#  ["DON'T", 'TIE', 'KNOT', 'WITH', 'TOO-TIGHT', 'FIANCE'],
#  ['DONOR', 'SHOULD', 'KEEP', 'KIDNEYS'],
#  ['PEDODONTIST', "CAN'T", 'FIDDLE', 'WHILE', 'SCHOOL', 'KEEPS'],
#  ['PEN', 'MIGHTIER', '--', 'AND', 'SAFER', '--', 'THAN', 'CONFRONTATION'],
#  ['POEM', 'PROVIDES', 'ANALYSIS', 'OF', 'PORNOGRAPHIC', 'FILMS'],
#  ["POEM'S",
#   'A',
#   'REFLECTION',
#   'OF',
#   "'TO",
#   'THINE',
#   'OWN',
#   'SELF',
#   'BE',
#   "TRUE'"],
#  ['PRANKSTER', 'EXPOSED', 'TO', 'LIFETIME', 'OF', 'REGRET'],
#  ['PREPAID', 'FUNERAL', 'CAN', 'BUY', 'PEACE', 'OF', 'MIND'],
#  ['PRIEST', 'AND', 'HIS', 'EX-GIRL:', 'BEST', 'TO', 'KEEP', 'DISTANCE'],
#  ['AN', 'UNSOLICITED', 'SEX', 'UPDATE', 'FROM', 'NEVADA'],
#  ['Dear', 'Abby:', 'Long-Lost', 'Papers', 'Missing', 'Soldier'],
#  ['NEIGHBORS', 'RUIN', 'WELCOME', 'FOR', 'BATS'],
#  ['NEED', 'FOR', 'HUMAN', 'ORGAN', 'DONORS', 'SERIOUS'],
#  ['Tall', 'Woman', 'Falls', 'Short', 'Values'],
#  ['Dear', 'Abby:', 'Honesty', 'Better', 'Policy', 'Than', 'Insurance'],
#  ['Marine', 'Pen', 'Pal', "'Operation'", '21', 'Success'],
#  ['Dear', 'Abby:', "Grandparents'", 'Love', 'Causing', 'Friction'],
#  ['Dear', 'Abby:', 'Girl-Watching', 'Is', 'Given', 'Black', 'Eye'],
#  ['Dear', 'Abby:', 'Getting', 'Root', 'Her', 'Hair', 'Aversion'],
#  ['Dear', 'Abby:', 'Farm', 'Kids', 'Had', 'Tougher', 'Row', 'Hoe'],
#  ['TOO', 'MUCH', 'IS', 'ENOUGH;', 'SO', 'DO', 'MORE', 'THAN', 'PRAY'],
#  ['TO', '6', 'DAUGHTERS-IN-LAW:', 'END', 'YOUR', 'TRIVIAL', 'PURSUIT'],
#  ['TIP', 'FOR', 'DINERS:', 'SHOW', 'COMPASSION', 'FOR', 'THE', 'DISABLED'],
#  ['X-RAYS', 'SETTLE', 'ARGUMENT', 'OF', "WHO'S", 'RIBBING', 'WHOM'],
#  ['YANKING', 'WELCOME', 'MAT', 'ON', 'THOUGHTLESS', 'GUESTS'],
#  ['ACCEPT', "DAUGHTER'S", 'BITTER', 'PILL', 'OR', 'THROW', 'OUT', 'LOVE'],
#  ['READERS', 'STEP', 'ON', 'BUSING', 'PUNISHMENT', 'COMPLAINT'],
#  ['YOU',
#   'KNOW,',
#   "IT'S",
#   'ABOUT',
#   'TIME',
#   'TO',
#   'GET',
#   'DOWN',
#   'TO',
#   'THE',
#   'BASICS',
#   'OF',
#   'LANGUAGE,',
#   'OK?'],
#  ['THANK',
#   'BAR-HOPPING',
#   'PAL',
#   'FOR',
#   'CLUE',
#   'TO',
#   'LIVE-IN',
#   "BOYFRIEND'S",
#   'TRUE',
#   'COLORS'],
#  ['ADVICE', 'FOR', 'NOVEMBER:', 'BE', 'AWARE', 'OF', 'YOUR', 'LIVER'],
#  ['READERS', 'RATE', 'ROOM', 'AND', 'BOARD', 'ADVICE'],
#  ['TAKE', 'THAT', 'DREAM', 'TRIP', 'BEFORE', 'TIME', 'RUNS', 'OUT'],
#  ['TAKE', 'BACK', 'SEAT,', 'QUIETLY,', 'OR', 'RISK', 'LOSING', 'BOYFRIEND'],
#  ['ALOOF', 'SON', "ISN'T", "'STOLEN'", 'PROPERTY'],
#  ['Mother-in-Law', 'Has', 'Her', 'Hands', 'Full'],
#  ['Dear',
#   'Abby:',
#   'Buddy',
#   'System',
#   'Is',
#   'Lousing',
#   'Up',
#   'Relationship',
#   'With',
#   'Boyfriend'],
#  ['NEIGHBOR', 'DESERVES', 'PUNCH', '--', 'AND', 'MORE'],
#  ['Dear', 'Abby:', 'Mom', 'Discovers', 'Son', 'Is', 'Sexually', 'Active'],
#  ['Dear', 'Abby:', "'Helpful'", 'Suggestions', 'Hinder', 'Stutterers'],
#  ['Letter', 'Alcoholism', 'Off', 'Mark?'],
#  ['VIOLENT', 'BEHAVIOR', 'SIGNALS', 'NEED', 'FOR', 'HELP'],
#  ['Different', 'Views', '011', 'Gifts', 'Multiples'],
#  ['HANDMADE', 'QUILT', 'UNCOVERS', 'THE', 'PRICE', 'OF', 'FRIENDSHIP'],
#  ["'THIS", "JOKE'S", 'ON', "ME':", 'ABBY'],
#  ["HE'LL",
#   'HAVE',
#   'TO',
#   'LOOK',
#   'LIKE',
#   'A',
#   'MILLION',
#   'TO',
#   'FIND',
#   'A',
#   'MATE'],
#  ['HELP', 'ABANDONED', 'MOTHER', 'AND', 'FORGET', 'PLEA', 'TO', 'DAD'],
#  ["HOTEL'S", 'LOST-AND-FOUND', 'POLICY', "DOESN'T", 'RING', 'TRUE'],
#  ['HUSBAND', 'HIDES', 'ILLITERACY'],
#  ['HUSBAND', 'MUST', 'SHIFT', 'TO', 'PATIENCE', 'TO', 'TEACH', 'DRIVING'],
#  ['HUSBAND', 'WAY', 'OUT', 'OF', 'BOUNDS', 'WITH', 'BLANKET', 'PLAY'],
#  ['UNITARIAN',
#   'CHURCH',
#   'MAY',
#   'BE',
#   'RELIGIOUS',
#   'SOLUTION',
#   'TO',
#   'MIXED',
#   'MARRIAGE',
#   'CEREMONY'],
#  ['Dear', 'Abby:', 'Where', "Snowball's", 'Chance', 'Is', 'Apropos'],
#  ['Dear', 'Abby:', 'Where', "There's", 'Smoke,', "There's", 'Ire'],
#  ['16',
#   'AND',
#   'PREGNANT,',
#   'DAUGHTER',
#   'CAN',
#   'BE',
#   'THANKFUL',
#   'FOR',
#   'THE',
#   'FUTURE',
#   'GRANDPARENTS'],
#  ['END', 'FEUD', 'BEFORE', 'BRIDE', 'GETS', 'TO', 'CHURCH'],
#  ['He', 'Tried', 'Rape,', 'May', 'G0', 'Her', 'Wedding'],
#  ['Dear', 'Abby:', 'Washing', 'Dog', 'Licked', 'Dish'],
#  ['Dear', 'Abby:', 'Want', 'Donate', 'Organs?', 'Carry', 'Card'],
#  ['Lie', 'Nurse,', 'Be', "'Grounded", "Life'"],
#  ['Dear', 'Abby:', 'Update', 'HOW', 'Survive', 'Tornado'],
#  ['Dear', 'Abby:', 'Turning', 'Thumbs', 'Down', 'Hitchhikers'],
#  ['Dear', 'Abby:', 'To', 'Be', 'Letter-Perfect', '0n', 'Overpopulation'],
#  ['Dear', 'Abby:', 'The', 'Symptoms', 'AIDS', 'Can', 'Be', 'Subtle'],
#  ['Dear', 'Abby:', 'The', 'Positive', 'Approach', 'Lighting', 'Up'],
#  ['Dear', 'Abby:', 'The', 'Pain', 'Her', "Family's", 'Get-Togethers'],
#  ['Dear', 'Abby:', 'The', 'Naked', 'Truth', 'About', "Guzzlin'", 'Geese'],
#  ['IF',
#   'FIDO',
#   'CLEANS',
#   'THE',
#   'DISHES,',
#   "DON'T",
#   'ASK',
#   'ABBY',
#   'TO',
#   'LUNCH'],
#  ['IF',
#   "THERE'S",
#   'A',
#   'TORNADO',
#   'COMING,',
#   "DON'T",
#   'OPEN',
#   'A',
#   'WINDOW,',
#   'HEAD',
#   'FOR',
#   'THE',
#   'BASEMENT'],
#  ['IN',
#   'TRUTH,',
#   'A',
#   '16-YEAR-OLD',
#   "SHOULDN'T",
#   'HAVE',
#   'TO',
#   'LIE',
#   'FOR',
#   'HER',
#   'PARENTS'],
#  ['INMATE', "CAN'T", 'VOLUNTEER', 'FOR', 'DEATH', 'AS', 'A', 'GUINEA', 'PIG'],
#  ['Head', 'Start', 'Liver', 'Awareness', 'Month'],
#  ['INSPIRED', 'POETIC', 'PARABLE'],
#  ['EQUAL', 'RIGHTS', 'FOR', 'ALL', 'STOPS', 'AT', 'THE', 'BATHROOM', 'DOOR'],
#  ['SON',
#   'NEEDS',
#   'TO',
#   'GIVE',
#   'FREELOADING',
#   'DAD',
#   'A',
#   'PUSH',
#   'TO',
#   'MOVE',
#   'OUT'],
#  ['FOR',
#   'THE',
#   'TUNES',
#   'IN',
#   'YOUR',
#   'HEAD,',
#   'WHISTLE',
#   'UP',
#   'A',
#   'MUSIC',
#   'SCHOOL'],
#  ['CONFESSION', 'WOULD', 'SCUTTLE', 'THE', 'BLACKMAILER'],
#  ['CON', 'MAN', 'HIDES', 'NAME,', 'ADDRESS', 'TO', 'DEFRAUD', 'PEN', 'PAL'],
#  ['FRIENDLY', 'JOGGER', 'KNEW', 'WHEN', 'TO', 'SLOW', 'THE', 'PACE'],
#  ["'DOGGIE", "DISHWASHER'", 'NOT', 'BEST', 'OF', 'FORM'],
#  ['CAN', 'THIS', 'MARRIAGE', 'BE', 'SAVED?', "DON'T", 'BOTHER'],
#  ["WOMAN'S", 'DATING', 'GAME', 'CAN', 'BACKFIRE'],
#  ['WOMAN',
#   'NEEDS',
#   'HELP:',
#   'HER',
#   'BURDEN',
#   'OF',
#   'HOPELESSNESS',
#   'IS',
#   'TOO',
#   'HEAVY',
#   'TO',
#   'CARRY'],
#  ['FAMILY', 'VS.', 'RELIGIOUS', 'FREEDOM', 'DEBATE', 'HEATS', 'UP'],
#  ['WIFE', 'THINKS', 'SIREN', 'COULD', 'STOP', 'TRUCKER'],
#  ['STUTTERING:', 'A', 'SERIOUS', 'HANDICAP', 'THAT', 'IS', 'NO', 'JOKE'],
#  ['WIFE', 'SHOULD', 'STAY', 'OUT', 'OF', 'HAGGLING', 'OVER', 'HEIRLOOM'],
#  ['GIFT', 'DEMAND', 'GETS', 'DESERVED', 'HANG-UP'],
#  ['GRANDPARENTS', 'NOT', 'EAGER', 'TO', 'BABY-SIT'],
#  ['Glad', 'See', 'Them', 'C0me--and', 'Leave'],
#  ['WIFE', 'ORDERED', 'TO', 'CALL', 'IT', 'QUITS'],
#  ['FAMILY', 'JOKES', 'SOMETIMES', 'GET', 'STALE'],
#  ['WIDOW', 'LOOKS', 'FOR', 'SILVER', 'LINING', 'IN', 'WW', 'II', 'INCIDENT'],
#  ['Gift', 'That', 'Keeps', 'On', 'Giving...', 'Trouble'],
#  ['FAMILY', 'HARMONY', "NEEDN'T", 'BE', 'BROKEN', 'OVER', 'CHINA'],
#  ["WHERE'S", 'THE', 'BEEF?', "IT'S", 'A', 'PUBLIC', 'POOL'],
#  ['SPERM', 'DONATION', 'A', 'RELATIVE', 'PROBLEM'],
#  ['WHEN', 'DISABLED', 'DINE', 'OUT'],
#  ["'NO", "SOLICITING'", 'MAY', 'BE', 'A', "SALESMAN'S", 'BEST', 'NEWS'],
#  ["WHAT'S",
#   'SNOOPING',
#   'MOTHER',
#   'TO',
#   'DO',
#   'WHEN',
#   'SHE',
#   'FINDS',
#   'THE',
#   'TRUTH',
#   'HURTS?'],
#  ["WHAT'S", 'A', 'BLOOD', 'DONOR', 'GOOD', 'FOR?', 'GOOD', 'FOR', 'LIFE'],
#  ['WHAT',
#   'YOU',
#   'CALL',
#   'STRANGERS',
#   'IS',
#   'SURE',
#   'TO',
#   'BE',
#   'A',
#   'MIS-TAKE'],
#  ["'PERFECT'", "SUITOR'S", 'GOT', 'A', 'BIG', 'PROBLEM'],
#  ['WANTING', 'RING', 'BACK', 'EXHIBITS', 'NO', 'CLASS'],
#  ['Giving', 'Children', 'New', 'Leash', 'Life'],
#  ['FAMILY',
#   'LOYALTY',
#   'OR',
#   'IRS',
#   'REWARD',
#   '--',
#   "THAT'S",
#   'THE',
#   'QUESTION'],
#  ['SHOWER', 'WOULD', 'DRENCH', 'DAMP', 'SITUATION'],
#  ['Dear', 'Abby:', 'Victim', 'Needs', 'Help', 'Through', 'Red', 'Tape'],
#  ['IS', 'A', 'SON', 'AT', '21', 'A', 'HOUSEGUEST?'],
#  ['KEY', 'TO', 'REGAINING', 'PRIVACY', 'IS', 'TO', 'RECLAIM', 'HOUSE', 'KEY'],
#  ['A', 'HANDSHAKE', 'CAN', 'BE', 'A', 'PAIN'],
#  ['KIDS', 'WILL', 'SEE', 'THROUGH', "DAD'S", 'PHONY', 'PROMISES'],
#  ['INTENTIONS', 'ASIDE,', 'LAW', 'HAS', 'BEEN', 'BROKEN'],
#  ['LAKE-DWELLERS:', 'SAY', 'NO', 'FIRMLY', 'TO', 'UNINVITED', 'GUESTS'],
#  ['SECOND', 'WIFE', 'WOULD', 'BE', 'ONE', 'TOO', 'MANY'],
#  ["LET'S", 'HEAR', 'IT', 'FOR', 'SALUTING', 'BACHELORS', 'OF', 'THE', 'WORLD'],
#  ['A', 'LOVER', 'TIED', 'TO', 'MOTHER'],
#  ['Dear', 'Abby:', 'Phone', 'Friend', 'Is', 'Trouble', 'Down', 'Line'],
#  ['LETTERS',
#   'FROM',
#   'HOME',
#   'WOULD',
#   'BE',
#   'WELCOME',
#   'GIFT',
#   'FOR',
#   'MARINES',
#   'IN',
#   'FOREIGN',
#   'LAND'],
#  ['A',
#   "MOTHER'S",
#   'UNUSUAL',
#   'PROBLEM:',
#   "SHE'S",
#   'ALLERGIC',
#   'TO',
#   'HER',
#   'OWN',
#   'SON'],
#  ['LETTING',
#   'CHILDREN',
#   'ANSWER',
#   'THE',
#   'BELL',
#   'OPENS',
#   'DOOR',
#   'TO',
#   'DANGER'],
#  ['SAVE',
#   'MARRIAGE',
#   'ISSUE',
#   'UNTIL',
#   'RELUCTANT',
#   'BOYFRIEND',
#   'IS',
#   'SOBER'],
#  ['LIFTING',
#   'A',
#   'PIANO',
#   'COULD',
#   'LAND',
#   'UNFIT',
#   'MAN',
#   'IN',
#   'AN',
#   'OBITUARY'],
#  ['A', 'POX', 'ON', 'THOSE', 'INSINCERE', 'INVITATIONS'],
#  ['LOVE', 'SURVIVES', 'THE', 'TEST', 'OF', 'TIME'],
#  ["LOVER'S", 'QUESTIONS', 'MAY', 'BE', 'AN', 'ANSWER'],
#  ['LOVESICK', 'NEIGHBOR', 'NEEDS', 'COUNSELING,', 'NOT', 'RELOCATION'],
#  ['Dear', 'Abby:', 'Penny', 'Pincher', 'Hurts', 'Marriage', 'Chances'],
#  ['Dear', 'Abby:', 'Other', 'Woman', "Doesn't", 'Want', 'Know'],
#  ['Dear', 'Abby:', 'No', 'Return', "Sister's", 'Contributions'],
#  ['KEEP', 'FANTASY', 'CAST', 'SECRET'],
#  ['Dear', 'Abby:', 'Repulsing', 'Invasion', 'Privacy'],
#  ['The', "'Hooker", "Look':", 'This', 'Too', 'Shall', 'Pass'],
#  ["IT'S", 'THANKSGIVING;', 'COUNT', 'YOUR', 'BLESSINGS'],
#  ['Dear', 'Abby:', 'Teaching', 'Children', 'About', "'Strangers'"],
#  ["It's", 'High', 'Time', 'Her', 'Retire', 'Welcome', 'Map'],
#  ['Dear', 'Abby:', 'Teaching', 'Children', 'About', "'Strangers‘"],
#  ['Dear', 'Abby:', 'Should', 'They', 'Report', 'Relatives', 'IRS?'],
#  ['IN', 'INTERRUPTED', 'MARRIAGES,', 'INTERRUPTION', 'COUNTS'],
#  ['PUNISHMENT', 'FITS', 'THE', 'CRIME', 'PERFECTLY'],
#  ['WIFE', 'IS', 'LEFT', 'PREGNANT', 'AND', 'IN', 'DOUBT'],
#  ['LONG-DISTANCE', 'ANALYSIS', 'REALLY', 'NO', 'CLOSER', 'TO', 'HOME'],
#  ['Dear',
#   'Abby:',
#   'A',
#   'Manly',
#   'Reﬂection',
#   'His',
#   'Life',
#   'Age',
#   'Of',
#   '13'],
#  ['TISSUE', 'WAD', 'PUTS', 'STOPPER', 'INTO', "CREEPS'", 'PEEP', 'SHOW'],
#  ['Dear', 'Abby:', 'A', 'Proud', 'Mom', 'With', 'Single', 'Daughter'],
#  ['IF', 'HE', 'LIKES', 'PORN,', 'SO', 'BE', 'IT'],
#  ['LETTERS', 'WOULD', 'NOT', 'SPELL', 'END', 'TO', "FRIEND'S", 'AFFAIR'],
#  ['IF',
#   'HAIRY',
#   'BODIES',
#   'MAKE',
#   'YOU',
#   'WANT',
#   'TO',
#   'SPLIT,',
#   'YOU',
#   'MIGHT',
#   'SEEK',
#   'HELP',
#   'OR',
#   'COVER-UP'],
#  ['Dear', 'Abby:', 'An', "'Above-Average'", 'Marriage', 'Goes', 'Bad'],
#  ["OVEREATING'S", 'AN', 'ADDICTION', 'THAT', 'NEEDS', 'ATTENTION'],
#  ['WHEN',
#   "YOU'VE",
#   'BEEN',
#   'ONE',
#   'OF',
#   'THE',
#   'PLAYERS,',
#   'EXPECT',
#   'TO',
#   'BE',
#   'PART',
#   'OF',
#   'THE',
#   'GAME'],
#  ['LETTERS', 'SHOW', 'THAT', 'MALE', 'NURSES', 'HAVE', 'IT', 'ROUGH'],
#  ['BREATHE', 'SOME', 'SENSE', 'INTO', 'A', 'SCENTED', 'COWORKER'],
#  ['BRAGGING', 'ABOUT', 'PRICES', 'CAN', 'BE', 'A', 'COSTLY', 'MISTAKE'],
#  ["GIRL'S", 'PAST', 'IS', 'NONE', 'OF', 'HIS', 'BUSINESS'],
#  ['MAKING', 'SHORT', 'WORK', 'OF', 'MIDWESTERN', "ROOMMATE'S", 'TALL', 'TALE'],
#  ['Love', 'Care', 'Needed', 'Beyond', 'Holidays'],
#  ['MOM', 'LAYS', 'DOWN', 'THE', 'LAW', 'LIKE', 'SARGE'],
#  ['PRUDENT',
#   'PARENTS',
#   'SHOULD',
#   'TEACH',
#   'CHILDREN',
#   'HOW',
#   'TO',
#   'HANDLE',
#   'FRIENDLY',
#   'STRANGERS'],
#  ['Dear', 'Abby:', 'Mother', "Can't", 'Force', 'Father', 'See', 'Child'],
#  ['Dear',
#   'Abby:',
#   'Must',
#   'Tell',
#   'Parents',
#   'Her',
#   'Fiance',
#   'Is',
#   'J',
#   'eWish'],
#  ['Dear', 'Abby:', 'N0.', '4', 'Wife', 'Fears', 'N0.', '5', 'Her', 'Future'],
#  ['FORGIVE', 'FROM', 'YOUR', 'HEART'],
#  ['TRUTH', 'IS', 'BEST', 'IN', 'UNWED', "DAUGHTER'S", 'INSEMINATION'],
#  ['CLERGY', 'MEMBER', 'ASKS,', "'SHOULD", 'I', 'OR', "SHOULDN'T", "I?'"],
#  ['PRENUPTIAL', 'AGREEMENT', 'LEAVES', 'POSTNUPTIAL', 'DOUBT'],
#  ['CHRISTMAS',
#   'SEASON',
#   'VOLUNTEERS',
#   'ASKED',
#   'TO',
#   'KEEP',
#   'SPIRIT',
#   'UP',
#   'ALL',
#   'YEAR'],
#  ["Who's", 'One', 'With', 'Problem', 'Here?'],
#  ['FEAR', 'OF', 'CANCER', 'IS', 'HEALTHY,', 'EVEN', 'AT', 'YOUNG', 'AGE'],
#  ['Final', 'Word', 'From', 'Put-Upon', 'Farmer'],
#  ['Dear', 'Abby:', 'Feeling', 'Poor', 'Among', 'Big', 'Spenders'],
#  ['TRUE',
#   'OR',
#   'FALSE:',
#   'IT',
#   'IS',
#   'BETTER',
#   'TO',
#   'HAVE',
#   'LOVED',
#   'AND',
#   'LOST?'],
#  ['FATHER', 'IS', 'EXCUSED', 'FROM', 'RISQUE', 'BACHELOR', 'PARTY'],
#  ['WORRIED',
#   'COUPLE',
#   'NEEDS',
#   'TO',
#   'FIND',
#   'OWN',
#   'BLESSING',
#   'FOR',
#   'MARRIAGE'],
#  ['Love', 'Him--but', "Don't", 'Turn', 'Your', 'Back'],
#  ['Dear', 'Abby:', 'Making', 'Prepaid', 'Funeral', 'Arrangements'],
#  ['TOO', 'MUCH', 'LOVEMAKING', 'FOR', 'WIFE'],
#  ["IT'S", 'TIME', 'TO', 'DUMP', 'TWO-TIMING', 'CAD'],
#  ['Dear', 'Abby:', 'Bachelor', 'Party', 'Puts', 'Father', '0n', 'Spot'],
#  ['Dear', 'Abby:', 'Thanks', 'Book', 'Memories'],
#  ['WARNING', 'FROM', 'JAIL:', "DON'T", 'DRIVE', 'DRUNK'],
#  ['Dear', 'Abby:', 'Single', 'Out', 'Day', 'Honor', 'Bachelors'],
#  ['Dear', 'Abby:', 'Considering', 'Diners', 'With', 'Special', 'Needs'],
#  ['Dear', 'Abby:', 'Dilemma', 'Slain', "Sailor's", 'ID', 'Bracelet'],
#  ["It's", 'Time', 'Cut', 'Tall', 'Tales', 'Down', 'Size'],
#  ['Dear', 'Abby:', 'Will', 'His', 'Last', 'Wish', 'Cause', 'Them', 'Pain?'],
#  ['TAX', "EVADER'S", 'WIFE', 'COULD', 'USE', "LAWYER'S", 'ADVICE,', 'TOO'],
#  ['Dear', 'Abby:', 'Request', 'Memento', 'Is', 'Compliment'],
#  ['MOTHER', 'CAMPAIGNS', 'AGAINST', 'CABBAGE', 'PATCH', 'DOLL', 'CRAZE'],
#  ['Dear', 'Abby:', "Roommate's", 'Boyfriend', 'Is', 'Always', 'There'],
#  ['YOUTHFUL', 'TRIANGLE', 'POINTS', 'TO', 'GRIEF', 'IN', 'ALL', 'DIRECTIONS'],
#  ['Dear', 'Abby:', 'Lovesick', 'Mate', 'Should', 'Seek', 'Counseling'],
#  ['Dear', 'Abby:', 'She', 'Feels', 'Betrayed', 'Family', 'Doctor'],
#  ['Dear', 'Abby:', 'Kidneys', 'Living', 'Donors', 'Not', 'Sought'],
#  ['Dear', 'Abby:', 'When', 'One', 'Lady', 'Friend', 'Is', 'Not', 'Enough'],
#  ['TELL-ALL',
#   'RELATIVE',
#   'SHOULD',
#   'TAKE',
#   'THE',
#   'HINT',
#   'AND',
#   'USE',
#   'RESTRAINT',
#   'IN',
#   'CHRISTMAS',
#   'LETTERS'],
#  ['Dear', 'Abby:', "We're", 'Not', 'Heavy,', "We're", 'His', 'Children'],
#  ['Dear', 'Abby:', 'Drunk', 'With', 'Love', 'Alcoholic'],
#  ['Dear', 'Abby:', "She's", 'Ready', 'Some', 'Blissful', 'Ignorance'],
#  ['Her', 'Father', 'Is', 'Turning', 'Deaf', 'Ear', 'Their', 'Help'],
#  ['Dear', 'Abby:', 'Composer', 'Is', 'Not', 'Sharp', 'With', 'Flats'],
#  ['Another', 'View', 'Numbers', 'Game'],
#  ['Dear', 'Abby:', "There'll", 'Be', 'N0', 'Bouquets', 'This', 'Daisy'],
#  ['Dear', 'Abby:', 'Catting', 'Around', 'Old', 'Neighborhood'],
#  ['Dear', 'Abby:', 'Holding', 'Man', "Who's", 'Running', 'Around'],
#  ['Dear', 'Abby:', 'Tangled', "Mother's", 'Tight', 'Apron', 'Strings'],
#  ['LANGUAGE', 'MAVENS,', 'TO', 'YOUR', 'CORNERS', 'FOR', 'ANOTHER', 'ROUND'],
#  ['BLOOD', "BANK'S", 'RULES', 'TOO', 'WEIGHTY', 'FOR', 'MOTHER'],
#  ['Dear', 'Abby:', 'Smoke', 'Signals', 'Behalf', 'Indian'],
#  ['NO', 'WASTE:', 'IMPLANTS', 'VITAL', 'FOR', 'LIFTING', 'SPIRITS'],
#  ['MOM', 'WANTS', 'TO', 'WEED', 'CABBAGE', 'PATCH', 'OF', 'SNOBBERY'],
#  ['NO', 'REVERSAL', 'ON', 'RING', 'ADVICE'],
#  ['VOLUNTEER', 'FIREMEN', 'HOT', 'OVER', 'LET-IT-BURN', 'INCIDENT'],
#  ['Teen', 'Father', 'Needs', 'Learn', 'Self—Control,', 'Birth', 'Control'],
#  ['THE',
#   'LONG',
#   'AND',
#   'SHORT',
#   'OF',
#   'IT',
#   'IS',
#   'THAT',
#   'THIS',
#   'WOMAN',
#   "DOESN'T",
#   'DESERVE',
#   'MR.',
#   'NICE',
#   'GUY'],
#  ['Child', 'Molestation', "Everyone's", 'Business'],
#  ['BITTERNESS', "DOESN'T", 'HELP', 'DIVORCED', "WOMAN'S", 'PLIGHT'],
#  ['Dear', 'Abby:', 'Would', 'You', 'Like', 'Be', 'Called', "'Missirs'?"],
#  ['NEW', 'LAW', 'GRAD', 'INSPIRED', 'TO', 'LARGE', 'DEGREE'],
#  ['NEVER', 'TOO', 'LATE', 'TO', 'SOLVE', 'MYSTERY', 'OF', 'SOLDIER'],
#  ['Dear', 'Abby:', 'Woman', 'Lather', 'Over', 'Shaving', 'Issue'],
#  ['Dear', 'Abby:', 'Prisoner', 'Would', 'Like', 'Be', 'Guinea', 'Pig'],
#  ['Dear', 'Abby:', 'Quilt', 'Bill', 'Puts', 'Her', '0n', 'Pins', 'Needles'],
#  ['Dear', 'Abby:', 'Recalling', 'Message', 'Worth', 'Repeating'],
#  ['EMBARRASSED',
#   'MOTHER',
#   'THINKS',
#   "IT'S",
#   'TIME',
#   'TO',
#   'TAKE',
#   'NOTE',
#   'OF',
#   'MISSING',
#   "THANK-YOU'S"],
#  ['Co-Worker', 'Offense', 'Good', 'Scents'],
#  ['Making', 'Prepaid', 'Funeral', 'Arrangements'],
#  ['PUNK', 'SON', 'CAN', 'BOW', 'OUT', 'OF', 'RECEPTION'],
#  ['SON', 'ADVISED', 'TO', 'END', 'AWOL'],
#  ['QUIZ', 'GIVES', 'THE', 'STRAIGHT', 'FACTS', 'ON', 'HOMOSEXUALITY'],
#  ['A', "CHILD'S", 'VICTIMIZATION', 'IS', 'ALWAYS', 'YOUR', 'BUSINESS'],
#  ["2'S", 'COMPANY', 'BUT', "3'S", 'REALLY', 'A', 'CROWD'],
#  ['SOUNDING',
#   'OFF',
#   'ON',
#   'EVERYDAY',
#   'EXAMPLES',
#   'OF',
#   'SLOPPY',
#   'SPEECH',
#   'HABITS'],
#  ['SHARP', 'WORDS', 'ON', 'WHETHER', 'WOMEN', 'SHOULD', 'SHAVE'],
#  ['A', 'Gift', 'Cash', 'Is', 'Right', 'Money'],
#  ['SOME', 'LEGWORK', 'CAN', 'UNCOVER', 'A', 'SEXY', 'DRESS'],
#  ['STUBBORN', 'DAD', "WON'T", 'HEAR', 'OF', 'HEARING', 'AID'],
#  ['ATTRACTED?',
#   'SOMETIMES',
#   'A',
#   'SMOKING',
#   'CIGARETTE',
#   'CAN',
#   'PUT',
#   'OUT',
#   'THE',
#   'FLAME',
#   'OF',
#   'LOVE'],
#  ['Christmas', 'Request', 'Leaves', 'Them', 'Cold'],
#  ['A', 'FORM', 'LETTER', 'THANK-YOU', 'IS', 'VERY', 'POOR', 'FORM'],
#  ['REQUEST', 'FOR', 'MODEST', 'KEEPSAKE', 'HONORS', 'DECEASED'],
#  ['REMARRIED',
#   "MOM'S",
#   'OPTIONS',
#   'ABOUND',
#   'FOR',
#   'COPING',
#   'WITH',
#   'FAVORITISM'],
#  ['ASK', 'FOR,', "DON'T", 'JUST', 'TAKE,', 'HOTEL', 'ITEMS'],
#  ['A',
#   'NATIONAL',
#   'HOLIDAY',
#   'HONORING',
#   'NATIVE',
#   'AMERICAN',
#   'INDIANS?',
#   "IT'S",
#   'LONG',
#   'OVERDUE'],
#  ["'ALONE", 'AFTER', "SCHOOL'", 'REQUIRED', 'READING', 'FOR', 'PARENTS'],
#  ['A', "CHILD'S", 'TEACHER', 'MAY', 'HELP', 'SOLVE', 'A', 'FAMILY', 'PROBLEM'],
#  ['Single', 'Moms', 'Raise', 'Kids,', 'Not', 'Eyebrows'],
#  ['Responding', "'Revolting'", 'Sight'],
#  ['Shrinking', 'Away', 'From', 'Getting', 'Help'],
#  ['She', 'Worries', 'About', 'His', 'Unfiled', 'Taxes'],
#  ['Son', 'Becomes', "'Guest'", 'J', 'ust', 'Get', 'Way'],
#  ['She', 'Married', 'Child...', "Man's", 'Body'],
#  ['Readers', 'Rip', 'Into', 'Letter', "'Torn'"],
#  ['She', 'Has', 'Answer', "Can't", 'Cure', 'Hives'],
#  ['FOR',
#   'WOMAN,',
#   '72-YEAR-OLD',
#   "BOYFRIEND'S",
#   "'BAKE-OFF'",
#   'THEORY',
#   'OF',
#   'LOVE',
#   'IS',
#   'HALF-BAKED'],
#  ["IT'S",
#   'WISE',
#   'TO',
#   'BE',
#   'WARY',
#   'WHEN',
#   'A',
#   'STRANGER',
#   'COMES',
#   'TO',
#   'THE',
#   'DOOR'],
#  ['PARENTS', 'OUT', 'OF', 'LINE', 'ON', 'RELIGION', 'STAND'],
#  ['Is', 'It', 'Love', 'Merely', 'Sexual', 'Attraction?'],
#  ['HE', 'LIED', 'AND', 'SHE', 'PRIED', '--', "THEY'RE", 'EVEN'],
#  ['TEEN', "SHOULDN'T", 'HIDE', 'FEELINGS'],
#  ['Dear', 'Abby:', 'Bragging', 'Could', 'Cost', 'Larry', 'His', 'Girlfriend'],
#  ['Dear', 'Abby:', 'Use', "'Em,", 'Lose', "'Em", 'Search', 'Mr.', 'Right'],
#  ['Dear', 'Abby:', 'Faith', 'That', 'Moved', 'Mountain', 'Misery'],
#  ['A', 'Prenuptial', 'Agreement', 'Boomerangs'],
#  ['Dear', 'Abby:', "Daughter's", 'Thank-Yous', 'Are', 'Too', 'Late'],
#  ['Dear', 'Abby:', 'Mother', 'Thinks', 'Snuggling', 'Is', 'Step', 'One'],
#  ['Dear', 'Abby:', 'Bristly', 'Reactions', 'Female', 'Hirsutism'],
#  ["'RAPUNZEL'",
#   'LETS',
#   'HAIRY',
#   'LEGS',
#   'HANG',
#   'OUT',
#   '--',
#   'TO',
#   'THE',
#   'DISMAY',
#   'OF',
#   'OTHERS'],
#  ['Bat', 'Lover', 'Sees', 'Red', 'Over', 'Cruel', 'Children'],
#  ['Dear', 'Abby:', 'When', 'Relatives', 'Extend', 'Their', 'Stay'],
#  ['Dear', 'Abby:', 'Vicious', 'Gossip', 'Can', 'Cause', 'Heartbreak'],
#  ['LOVING',
#   'LETTER',
#   'OF',
#   'ADVICE',
#   'CAN',
#   'MAKE',
#   'PRESENT',
#   'THE',
#   'BEST',
#   'CHRISTMAS',
#   'GIFT',
#   'OF',
#   'ALL'],
#  ['FORGET',
#   "'FALSE",
#   "MODESTY':",
#   'MALE',
#   'NURSES',
#   'GET',
#   'A',
#   'SHOT',
#   'IN',
#   'THE',
#   'ARM',
#   'FROM',
#   'READERS'],
#  ['Dear', 'Abby:', 'Easier', 'Get', 'Married', 'Than', 'Divorced'],
#  ['LANGUAGE',
#   'ABUSE',
#   'CAN',
#   'BE',
#   'LIKE',
#   'TOO',
#   'MUCH,',
#   "Y'KNOW,",
#   'RIGHT?'],
#  ['Dear',
#   'Abby:',
#   'Salvation',
#   'Army',
#   'Helps',
#   'Trace',
#   'Close',
#   'Relatives'],
#  ['Dear', 'Abby:', 'Carrying', 'Candor', 'Little', 'Bit', 'Too', 'Far?'],
#  ['Dear',
#   'Abby:',
#   'Niagara',
#   'Falls:',
#   'Which',
#   'Side',
#   'Dispute',
#   'Are',
#   'You',
#   'On?'],
#  ['At', '41,', 'She', 'Wants', 'Show', 'Off', 'Figure'],
#  ['Dear', 'Abby:', "Husband's", 'Vasectomy', 'Real', 'Shock', 'Her'],
#  ['Dear', 'Abby:', 'Degree', 'Inspiration', 'Legal', 'Matter'],
#  ['Advice', 'Kids', 'Left', 'Alone', 'After', 'School'],
#  ['Dear', 'Abby:', 'Classifying', 'Pushy', 'Mom,', 'Daughter'],
#  ['Bachelor', 'Party', 'Puts', 'Father', 'Bind'],
#  ['Dear',
#   'Abby:',
#   'Friendship',
#   'Goes',
#   'Dogs',
#   'Over',
#   "'Joke'",
#   'About',
#   'Gift'],
#  ['Dear', 'Abby:', 'Why', 'Quit', 'After', '30', 'Years', 'Together?'],
#  ['Dear', 'Abby:', 'Those', "'Invitations'", 'Present', 'Gift'],
#  ['Dear', 'Abby:', 'Artiﬁcial', 'Insemination', 'Hits', 'Snag'],
#  ['Dear', 'Abby:', 'Comments', 'Have', 'Ring', 'Passion'],
#  ['Dear', 'Abby:', 'So,', 'People', 'Misuse', 'Few', 'Words,', 'Right?'],
#  ['Word', 'Has', "Editor's", 'Dander', 'Upcoming'],
#  ['Dear', 'Abby:', "It's,", 'Basically,', 'You', 'Know,', 'Word', 'Abuse'],
#  ['YOUNG', "'ABBYS'", 'DROP', 'PEARLS', 'OF', 'WISDOM'],
#  ['Dear', 'Abby:', 'Correction', '0n', 'Oldest', 'Profession'],
#  ['THAT', 'PHONY', 'MARRIAGE', 'MAY', 'HONEYMOON', 'IN', 'JAIL'],
#  ['THERAPY', 'HELPS', 'FOR', 'DIVORCE'],
#  ['SOCKS', 'THE', 'LEAST', 'OF', 'NAVY', "WIFE'S", 'WOES'],
#  ["THERAPIST'S", 'SEXUAL', 'OFFER', 'BAD', 'MEDICINE'],
#  ['EXPECTANT', 'MOM', 'SNEAKING', 'TO', 'DOCTOR'],
#  ['HUFF', 'AND', 'PUFF', 'ON', 'RESTROOMS'],
#  ['ACCURACY',
#   'OF',
#   'DRUG',
#   'TESTS',
#   'A',
#   'GROWING',
#   'CAUSE',
#   'FOR',
#   'CONCERN'],
#  ['HOW', 'TO', 'LEND', 'RELATIVES', 'A', 'HAND,', 'RARELY', 'GET', 'BITTEN'],
#  ['TABLE', 'MANNERS', 'CAUSING', 'INTERNATIONAL', 'INDIGESTION'],
#  ['ADDRESS',
#   'IS',
#   'JUST',
#   'THE',
#   'NUMBER',
#   'FOR',
#   'FINDING',
#   'FATHER',
#   'AFTER',
#   'YEARS',
#   'OF',
#   'WONDERING'],
#  ['ALL', 'HOLIDAYS', 'ARE', 'ESTEEMED'],
#  ['TAKING', 'AIM', 'ON', 'HAVING', 'GUNS', 'AROUND', 'THE', 'HOUSE'],
#  ["'REMEMBER", "ME?'", 'A', 'GAME', 'THAT', 'FEW', 'ENJOY', 'PLAYING'],
#  ['VIRGINS', 'CAN', 'GET', 'PREGNANT'],
#  ['TEEN', 'MOM', 'SHOULD', 'ACT', 'AS', 'MOM,', 'NOT', 'KID'],
#  ['READER', 'SHARES', 'ENCOURAGING', 'WORDS'],
#  ['AIDS', 'IS', 'NOT', 'EASILY', 'CAUGHT'],
#  ['HOW', 'TO', 'JUNK', 'UNWANTED', 'SOLICITATIONS'],
#  ['ADOPTING', 'PARENTS', 'CRINGE', 'AT', "OTHERS'", 'NATURAL', 'COMMENTS'],
#  ["HERE'S", 'WHERE', 'TO', 'FIND', 'THE', 'THANKS', 'IN', 'THANKSGIVING'],
#  ['ADOPTIVE', "KIDS'", 'PARENTS', "CAN'T", 'RELATE', 'TO', 'RUDENESS'],
#  ['1', 'MAN,', '1', 'VOTE--AND', 'MANY', 'ERRORS'],
#  ['HOW',
#   'TO',
#   'GIVE',
#   'THIEVES',
#   'LICENSE',
#   'TO',
#   'STEAL',
#   'A',
#   'USED',
#   'CAR'],
#  ['HEROES', 'WHO', 'DEFIED', 'THE', 'ODDS'],
#  ['HOW', 'ONE', 'AIRLINE', 'SOLVED', 'A', 'WEIGHTY', 'TRAVEL', 'PROBLEM'],
#  ['HIDING', 'BALDNESS', "ISN'T", 'THE', 'WORST', 'PART'],
#  ['THE',
#   'FULL',
#   'STORY',
#   'ON',
#   'BIRTH',
#   'CONTROL',
#   'FOR',
#   'A',
#   'DISAPPOINTED',
#   'READER'],
#  ['YOU', "CAN'T", 'WIN', 'PLAYING', 'HOOKY'],
#  ['YOUNG', 'FATHER', 'NEEDS', 'SCHOOL'],
#  ['EASTERN',
#   'STAR',
#   'MATRON',
#   'SAYS',
#   "MEMBER'S",
#   'BEHAVIOR',
#   'RINGS',
#   'WITH',
#   'OUTRAGEOUSNESS'],
#  ['THERE',
#   'ARE',
#   'LIES,',
#   'AND',
#   'THERE',
#   'ARE',
#   'LIES,',
#   'AND',
#   "THAT'S",
#   'THE',
#   'PLAIN,',
#   'UNVARNISHED',
#   'TRUTH'],
#  ['TO', 'SMOKERS', 'AND', 'THEIR', 'LOVED', 'ONES'],
#  ['SOBERING',
#   'REALIZATION',
#   'CUTS',
#   'AN',
#   'UNIMPORTANT',
#   'WEIGHT',
#   'PROBLEM',
#   'TO',
#   'THE',
#   'BONE'],
#  ['MORE', 'VICTIMS', 'OF', 'SMOKE'],
#  ['SEX', 'STRIKES', 'SOME', 'AS', 'DULL'],
#  ['SELECTING',
#   'GIFTS',
#   'IS',
#   'AN',
#   'ART',
#   '.',
#   '.',
#   '.',
#   'SOMETIMES',
#   'PERFORMED',
#   'BY',
#   'THE',
#   'ARTLESS'],
#  ['BANNER', 'IMPROVES', 'ON', 'CAR-TROUBLE', 'TIP'],
#  ['LANDLORD',
#   'OUGHT',
#   'TO',
#   'THINK',
#   'AGAIN',
#   'ABOUT',
#   'BANISHING',
#   "READER'S",
#   'BELOVED',
#   'CAT'],
#  ['LEAVING',
#   'CHILD',
#   'IN',
#   'CLOSED',
#   'CAR',
#   'COULD',
#   'SPELL',
#   'DOOM,',
#   'ARIZONA',
#   'READER',
#   'REMINDS'],
#  ['LET', "'DORMANT", "ACCOUNT'", 'NOTICES', 'BE', 'A', 'WARNING'],
#  ['SEA', 'OF', 'LETTERS', 'KEEPING', 'SAILORS', 'FROM', 'RESPONDING'],
#  ['LETTER',
#   'ON',
#   'JOGGING',
#   'SUIT',
#   'GIFT',
#   'RUNS',
#   'AFOUL',
#   'WITH',
#   'READERS'],
#  ['ROMEO', 'HELPLESS', 'IF', 'HE', 'LIVES', 'AT', 'HOME'],
#  ['A', 'MARINE', 'CALLS', 'OUT', 'FOR', 'LETTERS'],
#  ['BEWARE', 'OF', 'MIXING', 'DRUGS', 'AND', 'ORAL', 'CONTRACEPTIVES'],
#  ['LIFE', 'LIVED', 'IN', 'HATE', 'WILL', 'PROBABLY', 'END', 'IN', 'PAIN'],
#  ["MOM'S", 'DEMAND', 'ON', 'SON', 'PUTS', 'RELATIONSHIP', 'TO', 'THE', 'TEST'],
#  ['BLADDER-CONTROL', 'WOES', 'NOT', 'A', 'SOLITARY', 'BURDEN'],
#  ['SAVE', 'A', 'CHILD', 'FROM', 'WHAT?'],
#  ['MANY', 'HEAR', 'MUSIC', "THAT'S", 'NOT', 'THERE'],
#  ['A', 'VOTE', 'FOR', 'THE', 'UNANNOUNCED', 'VISITOR'],
#  ["MARION'S",
#   'MESSAGE',
#   'SOUNDS',
#   'CLARION',
#   'CALL',
#   'FOR',
#   'A',
#   'LIKELY',
#   'SINNER'],
#  ['MASINA',
#   'TRAVELING',
#   'FAMILIAR',
#   'ROUTE',
#   'IN',
#   "FELLINI'S",
#   "'GINGER",
#   'AND',
#   "FRED'"],
#  ['BEWARE', 'OF', 'ANTIBIOTICS', 'WITH', 'THE', 'PILL'],
#  ['SHE', "DOESN'T", 'CARE', 'WHAT', "HE'S", 'MISSING--AND', 'VICE', 'VERSA'],
#  ['MOURNING', 'BLOCKS', 'A', 'WEDDING', 'AISLE'],
#  ['MUSIC', 'PLAYS', 'A', 'LIFE-SAVING', 'TUNE', 'IN', 'HEAD'],
#  ["HUSBAND'S", "'AFFAIR'", 'NOT', 'LESSENED', 'BY', 'ITS', 'DURATION'],
#  ['THESE', 'PARENTS', 'TAKING', 'NUDITY', 'IN', 'HOME', 'WAY', 'TOO', 'FAR'],
#  ['ABUSIVE',
#   'MOM',
#   'SHOWS',
#   'A',
#   'NEED',
#   'FOR',
#   'CALMING',
#   'VOICE',
#   'OF',
#   'ADVICE'],
#  ['U.S.PRODUCES', 'THOUGHTLESS', 'FOOD', 'BUYERS'],
#  ['U.S.', 'VISION', 'OF', 'CANADA', 'BORDERS', 'ON', 'IGNORANCE'],
#  ['SNAKE-PIT', 'STIGMA', 'HAUNTS', 'EX-MENTAL', 'PATIENTS'],
#  ['THIS', 'SHOWER', 'CAN', 'GO', 'DOWN', 'THE', 'DRAIN'],
#  ['2D,', '3D', 'OPINIONS', 'HEALTHY'],
#  ['TIPS', 'FOR', 'A', 'U.S.', 'BRIDE', 'MULLING', 'FOREIGN', 'RELATION'],
#  ['45',
#   'YEARS',
#   'NOT',
#   'TOO',
#   'LATE',
#   'TO',
#   'TELL',
#   'FAMILY:',
#   'BROTHER',
#   'RAPED',
#   'SISTER'],
#  ['TIPS',
#   'TO',
#   'HELP',
#   'YOU',
#   'PREVENT',
#   'FOREST',
#   'FIRES,',
#   'BURNING',
#   'HOUSES,',
#   'FLAMING',
#   'MISHAPS'],
#  ['TO',
#   'TELL',
#   'THE',
#   'TRUTH?',
#   'HONESTY',
#   'MAY',
#   'NOT',
#   'ALWAYS',
#   'BE',
#   'THE',
#   'BEST',
#   'POLICY',
#   'IN',
#   'RELATIONSHIPS.',
#   'IN',
#   'FACT,',
#   'A',
#   'FEW',
#   'WHITE',
#   'LIES',
#   'MAY',
#   'HELP.'],
#  ['IF', 'SMOKE', 'STINKS,', 'WHAT', 'ABOUT', 'EAU', 'DE', 'AROMAS?'],
#  ['INFIRM', 'TURNING', 'INTO', 'FAIR', 'GAME'],
#  ['TROOPS', 'ABROAD', 'NEED', 'SHARE', 'OF', 'HOLIDAY', 'CHEER'],
#  ['IT', "DOESN'T", 'ALWAYS', 'PAY', 'TO', 'MARRY', 'A', 'PROFESSIONAL'],
#  ["IT'D",
#   'BE',
#   'A',
#   'FAVOR',
#   'TO',
#   'EVERYBODY',
#   'IF',
#   "YOU'D",
#   'JUST',
#   'STOP',
#   'EATING',
#   'OUT'],
#  ["IT'S", 'CALLED', "'HUMANE'", 'FOR', 'REASON'],
#  ["IT'S", 'TIME', 'TO', 'BRIDGE', 'THE', 'MUMMY', 'GAP'],
#  ['RIGHT', 'WAYS', 'TO', 'DISCOVER', "WHAT'S", 'LEFT'],
#  ["DON'T", 'BE', 'A', 'PARTY', 'TO', 'DISINVITING', 'PLOY'],
#  ['YES,', 'THEY', 'DO', 'EAT', 'FUNNY', 'OVER', 'THERE'],
#  ['AN', 'AIDS-RISK', 'WARNING', "THAT'S", 'TOO', 'LATE', 'FOR', 'HER'],
#  ['MATRICULANTS', 'SUFFERING', 'IN', 'METICULOUS', 'NEGLECT'],
#  ['DANCER', 'CAN', 'GO', 'TOPLESS', 'AND', 'BELIEVE', 'IN', 'GOD,', 'TOO'],
#  ['CHARITY', 'IDEA', 'WAS', 'IN', 'THE', 'CARDS'],
#  ['CAUSE',
#   'OF',
#   'A',
#   'STROKE',
#   'USUALLY',
#   'WELLS',
#   'UP',
#   'FROM',
#   '1',
#   'OF',
#   '3',
#   'SOURCES'],
#  ['PEN-PAL', 'OPERATION', 'GETS', 'SALUTE', 'FROM', 'HIGH', 'SEAS'],
#  ['FAULTY', 'TEST', 'FOR', 'DRUGS', 'IMPERILS', "MARINE'S", 'FUTURE'],
#  ['CAN', 'A', "'THING", 'OF', "BEAUTY'", 'BE', 'A', 'SINNER?'],
#  ['PATERNAL', 'INSTINCTS', 'CAN', 'BE', 'RELATIVE,', 'FATHER', 'FINDS'],
#  ['DOUBLE', 'UP', 'ON', 'BREAST', 'SURGEONS,', '8', 'IS', 'ENOUGH'],
#  ['WRITE', 'STUFF', 'DURING', 'WW', 'II'],
#  ['WORDS',
#   'OF',
#   'CAUTION',
#   'FOR',
#   'A',
#   'COUPLE',
#   'OF',
#   'ADOLESCENTS',
#   'WHO',
#   'THINK',
#   "THEY'RE",
#   'IN',
#   'LOVE'],
#  ['SPORTING',
#   'HUSBAND',
#   'NOT',
#   'GAME',
#   'FOR',
#   'MARRIAGE;',
#   'GET',
#   'HELP',
#   'QUICK'],
#  ['ANSWER',
#   'TO',
#   'LETTER',
#   'SOCKS',
#   'IT',
#   'TO',
#   'A',
#   'SOLDIER',
#   'WHO',
#   'WAS',
#   'HOPING',
#   'TO',
#   'GET',
#   'HITCHED'],
#  ['ANAPOLOGYFORCOMMENT', 'ABOUT', "VETS'", 'SCHOOLING'],
#  ['PARENTS', 'SHOULD', 'KNOW', 'WHEN', "IT'S", 'TIME', 'TO', 'GO'],
#  ['SPREAD', 'ASHES', 'ON', 'BAD', 'HABIT'],
#  ['STOP', 'HOLDING', "EX-BOYFRIEND'S", 'GUN', 'TO', 'YOUR', 'HEAD'],
#  ['FAMILY', 'TIES', 'MAY', 'PRECLUDE', 'REKINDLING', 'AN', 'OLD', 'FLAME'],
#  ['STUDENT', 'MOVES', 'IN', 'WITH', 'BOYFRIEND', 'AND', 'GUILT'],
#  ['ODOR', 'COULD', 'BE', 'CAUSED', 'BY', 'A', 'MEDICAL', 'PROBLEM'],
#  ['ORGAN', 'DONOR', 'SUPPORTED', 'WITH', 'SUCCESS'],
#  ['ORGAN', 'DONOR', 'MAKES', 'HAPPY', 'HOLIDAYS', 'FOR', '3'],
#  ["'I", "CAN'T", 'BE', "DEAD--I'M", 'ONLY', "17'"],
#  ["GRANDDAUGHTER'S", 'CHOICE', 'OF', 'FRIENDS', 'IS', 'HER', 'BUSINESS'],
#  ['STRONG', 'LESSON', 'IN', "DAUGHTER'S", 'MURDER'],
#  ['ONE-WOMAN', 'MAN', 'HAS', 'A', "TWO-TIMIN'", 'WOMAN'],
#  ['NOT-SO-GRAND', 'CHILDREN', 'OVERWORK', 'GRANDMOTHER'],
#  ["CLERGYMAN'S", 'PRESENCE', 'CAN', 'BE', 'A', 'PRESENT,', 'TOO'],
#  ['GROUP', 'CAN', 'SOOTHE', 'THE', 'LOSS', 'OF', 'HAIR'],
#  ['NO', 'FONDNESS,', 'JUST', 'ABSENCE'],
#  ['CREEPS', 'GET', 'CHARACTER', 'ON', "FLORIDIAN'S", 'BUG', 'BEAT'],
#  ['AN',
#   'ODE',
#   'TO',
#   'SENDING',
#   'FLOWERS,',
#   'BY',
#   'AN',
#   'UNKNOWN--BUT',
#   'PROBABLY',
#   'BUDDING--POET'],
#  ['FOCUSING', 'ON', 'FINDINGS', 'OF', '2', "'SNEAKY'", 'WIVES'],
#  ['FOR', 'SPECIAL', 'DELIVERIES'],
#  ["NEIGHBOR'S",
#   'DESIRE',
#   'TO',
#   'REACH',
#   'OUT',
#   'PUTS',
#   'A',
#   '$200',
#   'TOUCH',
#   'ON',
#   'THE',
#   'TELEPHONE',
#   'BILL'],
#  ['CRUMBLINGS', 'ALONG', 'THE', 'COOKIE-SALE', 'TRAIL'],
#  ['FRIENDS', "SHOULDN'T", 'TELL', 'WIFE', 'ABOUT', "MAN'S", 'AFFAIR'],
#  ['AT',
#   'WEDDINGS,',
#   'GIVING',
#   'OVER',
#   'AND',
#   'OVER',
#   'IS',
#   'BETTER',
#   'THAN',
#   'WAITING',
#   'TO',
#   'RECEIVE'],
#  ['TRUTH',
#   'IS',
#   'BEST',
#   'WHEN',
#   'DEALING',
#   'WITH',
#   'AIDS',
#   'PATIENTS,',
#   'FRIENDS'],
#  ['INNOCENTS',
#   'MAY',
#   'BE',
#   'BURDENED',
#   'BY',
#   'MANDATORY',
#   'DRUG',
#   'TEST',
#   'LAW'],
#  ['DELUGE', 'ARRIVES', 'ON', 'DOT,AND', 'MUCH', 'OF', "IT'S", 'FURIOUS'],
#  ['WILL', 'REMEMBRANCE', 'DAYS', 'EVER', 'INCLUDE', 'HUCKSTERISM', 'DAY?'],
#  ['IF',
#   'THE',
#   'SURE-FIRE',
#   'METHOD',
#   "WON'T",
#   'WORK,',
#   'TEENS',
#   'SHOULD',
#   'SEE',
#   'FAMILY',
#   'PLANNERS'],
#  ['WIFE', 'SHOULD', 'LET', 'MEMORIES', 'DIE', 'TO', 'LET', 'MARRIAGE', 'LIVE'],
#  ['GIVE', 'HUBBY', 'A', 'BACKBONE'],
#  ["MOLESTER'S", 'EX-WIFE', 'OWES', 'HIS', 'NEW', 'BRIDE', 'AN', 'EXPLANATION'],
#  ['A', 'WORLD', 'OF', 'SYMBOLS', 'ON', 'LIBERTY'],
#  ['DENYING', 'KIDS', 'A', 'KITTEN', "WASN'T", 'HUMANE'],
#  ['GIVING', 'HER', 'HUSBAND', 'THE', 'MOST', 'SPECIAL', 'GIFT'],
#  ['GLOVES', 'OFF', 'ON', 'PRIVACY'],
#  ['MISCONCEPTIONS',
#   'ABOUT',
#   'LASSIE',
#   'FORCE',
#   'TRAINER',
#   'TO',
#   'SIT',
#   'UP,',
#   'SPEAK'],
#  ['AS', 'EACH', 'YEAR', 'PASSES,', 'THE', 'PAST', 'JUST', 'GETS', 'WORSE'],
#  ['MARRIAGE', 'IS', 'OUT', 'TO', 'LUNCH'],
#  ['MARRIAGE',
#   'SEEMS',
#   'TO',
#   'BE',
#   'A',
#   'HABEAS',
#   'CORPSE',
#   'NOW',
#   'THAT',
#   "WIFE'S",
#   'AN',
#   'ATTORNEY'],
#  ['GRANDSON,', '3,', 'SHOULD', 'ATTEND', "GRANDMA'S", 'FUNERAL'],
#  ['BROTHERLY', 'LOVE', "ISN'T", 'NECESSARY'],
#  ['GRIEF', 'OVER', 'SON', 'BROUGHT', 'ON', 'COMPULSIVE', 'STEALING'],
#  ['SILENT', 'LOVE', 'BETTER', 'THAN', 'NONE', 'AT', 'ALL'],
#  ["IT'S", 'NEVER', 'TOO', 'LATE', 'FOR', 'CHILDREN', 'TO', 'MEND', 'FENCES'],
#  ["A'LITTLE'", 'FLING', 'TURNS', 'INTO', 'A', 'FAMILY', 'AFFAIR'],
#  ['COMING', 'TO', 'TERMS', 'WITH', 'RELATIONSHIPS', "ISN'T", 'EASY'],
#  ['MONEY', 'CAN', 'BEAT', 'MIXER', 'AS', 'PERFECT', 'WEDDING', 'GIFT'],
#  ["DAUGHTER'S", 'ABOUT-FACE', 'DESERVES', 'A', 'CLOSER', 'LOOK'],
#  ['CHILD', 'SUPPORT', "SHOULDN'T", 'GO', 'DIRECTLY', 'TO', 'THE', 'CHILD'],
#  ['LET', 'THINKING', 'HALF', 'DECIDE'],
#  ["MOM'S",
#   'RIGHT',
#   'IN',
#   'NOT',
#   'FOOTING',
#   'BILL',
#   'FOR',
#   'TARDY',
#   'WEDDING',
#   'PARTY'],
#  ['CHANCES',
#   'OF',
#   'CATCHING',
#   'AIDS',
#   'IN',
#   'PUBLIC',
#   'SWIMMING',
#   'POOL',
#   'CONSIDERED',
#   'REMOTE'],
#  ['COMPANIONSHIP', 'WITHOUT', 'GUILT', 'FOR', 'LONELY', 'HUSBAND'],
#  ['DO', 'MEN', 'PREFER', 'BLONDS?', 'ABBY', 'TAKES', 'A', 'SURVEY'],
#  ['LIVING', 'WITH', 'IN-LAWS', 'MAKES', 'FOR', 'ONE', 'UNHAPPY', 'WIFE'],
#  ['MORE', 'THAN', '1', 'WAY', 'TO', 'START', 'A', 'CLICHE'],
#  ['KEEPING',
#   "SON'S",
#   'HOMOSEXUALITY',
#   'IN',
#   "PARENTS'",
#   'CLOSET',
#   'NOT',
#   'GOOD'],
#  ['RELATIONSHIP', "SHOULDN'T", 'END', 'WITH', 'HIS', 'PROPOSITION'],
#  ['KEEP', 'HONOR', 'IN', 'THE', 'FAMILY'],
#  ["CAN'T", 'CONCEIVE?', 'TRY', 'CHANGING', 'YOUR', 'SHORTS'],
#  ['LOAN', 'LIABILITY', 'CAN', 'BE', 'RELATIVE', 'MATTER'],
#  ["'A",
#   'PRAYER',
#   'FOR',
#   "MAMA'",
#   'KEEPS',
#   'MEMORIES',
#   'ALIVE',
#   'AFTER',
#   'MOTHER',
#   'IS',
#   'GONE'],
#  ['MR.', 'HYDE', 'AT', 'THE', 'WHEEL', 'NEEDS', 'SOME', 'COUNSELING'],
#  ["DON'T", 'FEED', 'THE', 'DOGMA'],
#  ['FOR', 'SOME,', "IT'S", 'BETTER', 'TO', 'GET'],
#  ['REQUEST', 'DRAWS', 'WASHING-TON', 'OF', 'MAIL'],
#  ['LOW-COST', 'HELP', 'AVAILABLE', 'FOR', 'ABUSERS'],
#  ['FOR',
#   'HUSBAND,',
#   'NEATNESS',
#   'IS',
#   'A',
#   'FETISH',
#   'BY',
#   'ABIGAIL',
#   'VAN',
#   'BUREN.'],
#  ['REPEATING:', 'HOLLOWEEN', 'MISTREATED'],
#  ['CROSS-DRESSING', "NEEDN'T", 'RUIN', 'THEIR', 'LOVE'],
#  ['12-YEAR-OLD', 'HAS', 'A', 'DRINKING', 'PROBLEM'],
#  ['AT',
#   '18,',
#   'ILLEGITIMATE',
#   'DAUGHTER',
#   'CAN',
#   'HANDLE',
#   'DISCOVERY',
#   'OF',
#   'HER',
#   'WORTHLESS',
#   'FATHER'],
#  ['HOLDOUT',
#   'BACKERS',
#   'HONOR',
#   'DAY',
#   'WHEN',
#   'SEX',
#   "DIDN'T",
#   'GO',
#   'FOR',
#   'SONG'],
#  ['ON', 'THE', 'SPOT?', 'AUTHOR', 'GREETS', 'YOUR', 'PROBLEMS'],
#  ["DON'T", 'KEEP', 'SCORE,', 'JUST', 'KEEP', 'UP'],
#  ['RAPE', 'IS', 'RAPE,', 'AND', "MOTHER'S", 'WRONG'],
#  ['YES,',
#   'YOU',
#   'CAN',
#   'DO',
#   'SOMETHING',
#   'TO',
#   'EASE',
#   'THE',
#   'AGONY',
#   'OF',
#   'LABORATORY',
#   'ANIMALS'],
#  ['VIVISECTION', 'ITEM', 'SPEAKS', 'FOR', 'ITSELF'],
#  ['STORED-UP', 'RESENTMENT', 'CAN', 'STIFLE', 'PILLOW', 'TALK'],
#  ['HINDSIGHT', 'IS', '20-20,', 'WITH', 'REGRETS'],
#  ['ANTI-DRUG', 'CLUBS', 'BEGIN', 'TO', 'GROW', 'FROM', 'WORD', "'NO'"],
#  ["HERE'S", 'ANOTHER', 'ODE', 'TO', 'TAKING', 'IT', 'SLOW'],
#  ['WHY', 'ASIAN-AMERICANS', 'RESENT', "'WHAT", 'ARE', "YOU?'"],
#  ['TAKING',
#   'AWAY',
#   'A',
#   'DRUNK',
#   "NEIGHBOR'S",
#   'CAR',
#   'KEYS',
#   'WAS',
#   'THE',
#   'PROPER',
#   'ROUTE',
#   'TO',
#   'TAKE'],
#  ['NEXT',
#   'TIME',
#   'YOU',
#   'ATTEND',
#   'A',
#   'CHURCH',
#   'SERVICE,',
#   'WHY',
#   'NOT',
#   'BE',
#   'ALIVE',
#   'TO',
#   'ENJOY',
#   'IT?'],
#  ['WHEN', 'IS', "'GAY'", 'GAY?'],
#  ['HUBBY', 'WASH', 'IS', 'AN', 'AGITATION'],
#  ['WIDOW', "SHOULDN'T", 'FOLLOW', 'THE', 'FANTASY'],
#  ['HERPES', 'TRANSMISSION', 'CAN', 'BE', 'CONTROLLED', 'WITH', 'CARE'],
#  ['THIS', 'CALLS', 'FOR', 'AIDS', 'TEST,', 'NOT', 'PANIC'],
#  ['HEIRLOOM', 'RIGHTFULLY', 'BELONGS', 'TO', 'WHOM', "IT'S", 'GIVEN'],
#  ['ANIMALS', 'BEST', 'GUINEA', 'PIGS?'],
#  ['FACE-TO-FACE',
#   'CONFRONTATION',
#   'COULD',
#   'SAVE',
#   'A',
#   'PHONEY',
#   'ONE-WAY',
#   'FRIENDSHIP'],
#  ['WIFE',
#   'OF',
#   'VIETNAM',
#   'VET',
#   'FINDS',
#   'HAPPINESS',
#   'IN',
#   'MARRIAGE',
#   'TO',
#   'HANDICAPPED',
#   'MAN'],
#  ['ANGER', 'NO', 'CURE', 'FOR', 'ABUSE', 'REVELATION'],
#  ["HE'S", 'A', 'LOSER', 'IF', 'HE', 'LOST', 'FAITH'],
#  ['TAKE', 'CARE', 'IN', 'HANDLING', 'SEX', 'CHARGES'],
#  ['HUSBAND', 'IN', 'THE', 'DOGHOUSE', 'SHOULD', 'LOOK', 'AT', 'HIS', 'LEASE'],
#  ['NEVER', 'TOO', 'LATE', 'TO', 'TELL', 'WHY', 'BROTHER', 'IS', 'SCORNED'],
#  ['HOW', 'COUPLE', 'CAN', 'HEIGHTEN', 'THE', 'WEDDING', 'EXPERIENCE'],
#  ['AROUND',
#   'COWORKERS,',
#   'HOMETOWN',
#   'PALS',
#   'SHOULD',
#   'LET',
#   'AULD',
#   'LANG',
#   'SYNE',
#   'BE',
#   'FORGOT'],
#  ["SON'S", 'JEALOUSY', 'HAS', 'DATING', 'MOM', 'ON', 'THE', 'ROPES'],
#  ['NO', 'INDEFINITE', 'VISITS,', 'AND', "THAT'S", 'DEFINITE'],
#  ['VISIT', 'FROM', 'POLICE', 'MAY', 'CURE', 'CARE-HOME', 'THEFT'],
#  ['GUIDE', 'SPELLS', 'OUT', "VETERANS'", 'RIGHTS'],
#  ['WALK-IN',
#   'GUESTS',
#   'ARE',
#   'SERVED',
#   'RIGHT',
#   'BY',
#   'HOSTESS',
#   'WHO',
# ...
#  ['HERE', 'ARE', 'MORE', 'WAYS', 'TO', 'SKIN', 'A', 'CAT,', 'ER,', 'CLICHE'],
#  ['29-YEAR-OLD', 'VIRGIN', 'WANTS', 'TRUE', 'LOVE', 'FIRST,', 'SEX', 'LATER'],
#  ['FATHER-AND-SON', 'TALK', 'IS', 'LONGOVERDUE'],
#  ["'NO", "PANTS'", 'POLICY', 'JUST', 'SKIRTS', 'THE', 'ISSUE'],
#  ['HIGH', 'SCHOOL', 'DROPOUT', 'CAN', 'COME', 'OUT', 'OF', 'CLOSET'],
#  ['NEIGHBOR',
#   'WOULD',
#   'BE',
#   'RELIEVED',
#   'IF',
#   'KIDS',
#   'MADE',
#   'RELIEF',
#   'A',
#   'MORE',
#   'PRIVATE',
#   'MATTER'],
#  ['MOST',
#   'READERS',
#   'AGREE',
#   'THAT',
#   'THE',
#   'BIRTH',
#   'OF',
#   'A',
#   'BABY',
#   'SHOULD',
#   'BE',
#   'A',
#   'FAMILY',
#   'AFFAIR'],
#  ['WIFE',
#   'SHOULD',
#   'WAKE',
#   'UP',
#   'TO',
#   'THE',
#   'TRUTH',
#   'ABOUT',
#   'HER',
#   'SLEEP-TALKING',
#   'HUSBAND'],
#  ['JEALOUS', 'WIFE', 'NEEDS', 'COUNSELING,', 'CONSOLING'],
#  ['A', 'TORN', "SHIRT'S", 'OK', 'AT', 'HOME,', 'BUT', 'TROUSERS?', 'NEVER!'],
#  ['SON', "CAN'T", 'BE', 'WISHED', 'AWAY'],
#  ["LITTLE'S", 'CHANGED', 'FOR', 'FREE', 'AGENTS'],
#  ['MARRIED', 'TO', 'AN', 'ILLEGAL', 'ALIEN'],
#  ["WHAT'S", 'IN', 'A', 'NAME?', 'SOMETIMES', 'PAIN'],
#  ["MARINES'", 'SURVIVORS', 'FILL', 'BEIRUT', 'VOID'],
#  ['WEDDING', 'PHOTOS', 'IN', 'THE', 'BATHROOM?'],
#  ['FAITHFUL', 'PETS', 'DESERVE', 'GENTLE', 'END'],
#  ['EVERYBODY', 'MUST', 'KEEP', 'DRUNK', 'DRIVERS', 'OFF', 'ROAD'],
#  ['LOST', 'RELATIVE?', 'TRY', 'SALVATION', 'ARMY'],
#  ["EX'S", 'SLEEPING', 'PLANS', 'BOTHER', 'MOM'],
#  ['COURTESY', 'IS', 'JUST', 'A', 'PHONE', 'CALL'],
#  ['A', 'VIETNAM', 'VETERAN', 'MAKES', 'A', 'PLEA', 'FOR', 'TEARS'],
#  ['A', 'VERY', 'SPECIAL', '70-YEAR', 'MARRIAGE'],
#  ['A', 'REALISTIC', 'LOOK', 'AT', 'ABANDONED', 'PETS'],
#  ['LIVE-IN', 'BOYFRIEND', "ISN'T", 'CAUSE', 'TO', 'SHUN', 'DAUGHTER'],
#  ['LITTLE', "GIRL'S", 'PLIGHT', 'SHOCKS', 'READER'],
#  ["'DEAR'",
#   'SISTERS',
#   'AN',
#   'INSIDE',
#   'PEEK',
#   'AT',
#   'RIVAL',
#   'TWINS',
#   'ABBY',
#   'AND',
#   'ANN'],
#  ["FALL'S",
#   'PLEASURES',
#   'THE',
#   'BEST',
#   'BOOKS',
#   'OF',
#   'THE',
#   'COMING',
#   'SEASON'],
#  ['SOMBER', 'LAMENT', 'FOR', 'YOUNG', 'DRIVERS'],
#  ['WOMEN',
#   'BERATE',
#   'MEN',
#   'IN',
#   'NEW',
#   'HITE',
#   'BOOK',
#   'ON',
#   'SEX,',
#   'LOVE',
#   'IN',
#   "'80S"],
#  ['WHICH', "'ME'", 'DO', 'I', 'SEE', 'LURKING', 'IN', 'MY', 'CLOSET?'],
#  ['WHY', 'DO', 'DINERS', 'PREFER', 'DIRTY', 'TABLES?'],
#  ['A', 'BIT', 'OF', 'ADVICE', 'OVER', 'TEA'],
#  ['WIFE', 'HURT', 'BY', "HUBBY'S", 'PUT-DOWNS'],
#  ['A', 'BIG', 'BOOST', 'FOR', 'THE', "'LITTLE", "PEOPLE'"],
#  ['IN',
#   'THE',
#   'HIVES',
#   'MYSTERY,',
#   'ANSWERS',
#   "AREN'T",
#   'EXACTLY',
#   'BREAKING',
#   'OUT',
#   'ALL',
#   'OVER'],
#  ['A', "'HARMLESS'", 'AFFAIR', 'CAN', 'LEAD', 'ONLY', 'TO', 'REGRET'],
#  ['SICK', 'PUPPY', 'SAVES', 'LIFE', 'OF', 'RESCUER'],
#  ['HUMAN', 'ERROR', 'FILLS', 'COMPUTER', 'WORLD'],
#  ['SIMPLE', 'WAYS', 'TO', 'KEEP', 'SOMEONE', 'SPECIAL', 'HAPPY'],
#  ['WIFE', 'LIVES', 'TO', 'RUE', 'DEATH', 'NEWS'],
#  ["GRAD'S", 'PERSONAL', 'STOCK', 'MAY', 'DIVE'],
#  ['GUNS,', 'KIDS', 'AND', 'SAFETY'],
#  ['SMOKEOUT', 'CAN', 'HELP', 'CLEAR', 'THE', 'AIR'],
#  ['USE', 'CAUTION', 'WHEN', 'BANDING', 'BIRDS'],
#  ['GUEST', 'WORE', 'OUT', 'HIS', 'WELCOME'],
#  ['UNTIMELY', 'CHIMES', 'CAUSE', 'FOR', 'UNREST'],
#  ['A', 'DIVORCE', 'TECHNICALITY', 'ON', 'IN-LAWS'],
#  ['SAVE', 'A', 'TATTOO?', 'TAN', 'HIS', 'HIDE!'],
#  ['WORDS', 'CAN', 'ABUSE', 'YOUR', 'CHILD,', 'TOO'],
#  ['CALL', 'TO', 'HELP', 'BLOOD', 'BANKS'],
#  ['HAPPY', 'ENDING', 'TO', 'LONG', 'SEPARATION'],
#  ['A', 'MESSAGE', 'FOR', 'ALL', 'CAR', 'PHONE', 'USERS'],
#  ['FIRE', 'PREVENTION', 'TIPS', 'FOR', 'ALL', 'SEASONS'],
#  ['CHEWING', 'OUT', 'TOBACCO-CHEWERS'],
#  ['SOME', 'HELPFUL', 'HINTS', 'FOR', 'VISITORS'],
#  ["LAWYERS'", 'FAMILIES', 'HAVE', 'TO', 'EAT,', 'TOO'],
#  ['A', 'LOOK', 'BACK', 'AT', '1987,', 'FROM', 'THE', 'BAKKERS', 'TO', 'BORK'],
#  ['SECRETARIES', 'RUE', 'THEIR', "'DAY'"],
#  ["LAB'S", 'ERROR', 'LEADS', 'TO', 'FAMILY', 'TRAGEDY'],
#  ['SURVEY:', 'WIVES', 'ARE', 'MORE', 'FAITHFUL'],
#  ['SEPARATE', 'BEDS', 'IS', 'HOUSE', 'RULE'],
#  ['A', 'HOT', 'TIP', 'ON', "'86", 'SMOKEOUT'],
#  ['HICCUP', "'CURES'", 'FAIL', 'TO', 'HELP', 'CHARLIE'],
#  ['KEEPING', 'BURGLARS', 'AT', 'BAY', 'WHILE', "YOU'RE", 'AT', 'PLAY'],
#  ['CANARY', 'OWNER', 'SINGS', 'A', 'SAD', 'SONG'],
#  ['SHE', 'FEARS', 'LIFE', 'HAS', 'PASSED', 'HER', 'BY'],
#  ['A', 'GIVEN', 'GIFT', 'IS', 'OUT', 'OF', 'YOUR', 'HANDS'],
#  ["SHE'S", 'GRATEFUL', 'THAT', 'HUBBY', 'HAS', 'A', "CHEATIN'", 'HEART'],
#  ['HIS', 'PERSONAL', 'TOUCH'],
#  ['HISTORY', 'RECORDED', 'IN', 'FAMILY', 'LETTERS'],
#  ["SON'S", 'GAY', 'LIFESTYLE', 'STUNS', 'PARENTS'],
#  ['FLUSHING', 'OUT', 'WASHROOM', 'TAGS'],
#  ['ADULT', 'LOVER', 'ACTS', 'UNMANLY'],
#  ['MORE', 'KUDOS', 'FOR', 'TEENAGE', 'VIRGIN'],
#  ['NEWBORNS', 'WITH', 'TEETH:', "IT'S", 'A', 'BABY', 'BOOM!'],
#  ['OVERSEAS', 'MAIL', 'BRINGS', 'SMILES,', 'TEARS'],
#  ['AN', "'AIDS-FREE'", "SINGLES'", 'CLUB', 'IS', 'NO', 'GUARANTEE'],
#  ['MOM', 'FEARS', "GIRL'S", "'PEN", "PAL'", 'IS', 'REAL'],
#  ['RASH', 'ACT', 'TURNS', 'TREASURE', 'INTO', 'TRASH'],
#  ['READERS', 'RAISE', 'A', 'RACKET', 'OVER', 'NOISE'],
#  ['TV', 'highlights.'],
#  ['ABBY', "'BLEW'", 'ADVICE', 'TO', "GAY'S", 'MOM'],
#  ['BOOK', 'CAN', 'AID', 'FAMILIES', 'OF', 'MENTALLY', 'ILL'],
#  ['TOYS', 'WILL', 'NEVER', 'REPLACE', 'PARENTS'],
#  ['TEENAGER', 'RESENTS', "PARENTS'", 'LECTURES'],
#  ["ABBY'S", 'TIPS', 'FOR', 'HOLIDAY', 'GIFT', 'GIVING'],
#  ['BE', 'WARY', 'OF', 'BARKING,', 'GROWLING', 'DOGS'],
#  ["BULLS'", 'COLLINS', 'LOOKING', 'FOR', 'A', 'LITTLE', 'ADVICE'],
#  ['BORN', 'WITH', 'A', 'TOOTH?', 'TELL', 'US', 'THE', 'TRUTH'],
#  ['DISABLED', 'NEED', 'LOVE,', 'NOT', 'REJECTION'],
#  ["TEEN'S", 'LOVE', 'IS', 'JUST', 'INFATUATION'],
#  ['AIDS', 'MOVIE', 'A', 'MUST', 'FOR', 'ALL'],
#  ['BE', 'THANKFUL', 'ON', 'THANKSGIVING', 'DAY'],
#  ['NICE',
#   'GUYS',
#   'THEY',
#   'SLEEP',
#   'ALONE.',
#   "THEY'RE",
#   'SENSITIVE.',
#   'THEY',
#   'CRAVE',
#   'COMMITMENT.',
#   'IN',
#   'OTHER',
#   'WORDS,',
#   "THEY'RE",
#   'NOT',
#   'REAL',
#   'MEN.'],
#  ['ATTITUDE', 'CAN', 'LAND', 'A', 'SUMMER', 'JOB'],
#  ['NO', 'CHARGE', 'FOR', "GOD'S", 'FREE', 'GIFTS'],
#  ['DOGS', 'ARE', 'WELCOME', 'AT', 'SOME', 'MOTELS'],
#  ['POETRY', 'IN', 'STEP', 'WITH', 'THE', 'MILITARY', 'RANKS'],
#  ['TIME', 'FLEETING', 'FOR', 'WOULD-BE', 'MOM'],
#  ['THERE', 'ARE', '2', 'SIDES', 'TO', 'LIVING', 'AS', 'TWINS'],
#  ['ON', 'CROSSING', 'GENDER', 'BARRIER'],
#  ['ANY', 'WOMAN', 'CAN', 'BE', 'ABUSE', 'VICTIM'],
#  ['OUT', 'WITH', 'THE', 'BOYS', 'OR', 'JUST', 'PLAIN', 'OUT?'],
#  ['PHILANDERING', 'SPOUSE', 'RISKS', 'AIDS'],
#  ['ONLY', 'BRAVE', 'CAN', 'FORGIVE'],
#  ['PROS', 'AND', 'CONS', 'OF', "'DROP-IN'", 'CLERGY'],
#  ['ONLY', 'PURSE', 'STRINGS', 'TIE', 'FATHER,', 'SON'],
#  ['THE', 'FAME', 'GAME', 'IS', 'DIFFERENT', 'FOR', 'TWINS'],
#  ['THAT', 'SHOTGUN', 'BLAST', "WON'T", 'CURE', 'A', 'PEEPING', 'TOM'],
#  ['READERS',
#   'TOSS',
#   'MONKEY',
#   'WRENCH',
#   'INTO',
#   'SEARCH',
#   'FOR',
#   "POEM'S",
#   'AUTHOR'],
#  ['THERAPY', 'COULD', 'SETTLE', 'THE', 'AFFAIR'],
#  ['OH,', 'THOSE', 'FRENCH-CUT', 'SWIMSUITS!'],
#  ["'DOCTOR'", 'TITLE', 'GETS', 'CONFUSING'],
#  ['SNUFF', 'DIPPER', 'TURNS', 'OFF', 'SPOUSE'],
#  ['FBI',
#   'MUST',
#   'TELL',
#   'A',
#   'LETTER',
#   'WRITER',
#   'IF',
#   'A',
#   'FILE',
#   'BEARS',
#   'AN',
#   'OLD',
#   'SCAR'],
#  ['SILENT--RESENTFUL--PARTNER',
#   'IN',
#   'GIFT-GIVING',
#   'SHOULD',
#   'PIPE',
#   'UP',
#   'FOR',
#   'APPRECIATION'],
#  ['ABUSED', 'WOMAN', 'BATTLES', 'BLACKMAIL'],
#  ['SKIRTS',
#   'VS.',
#   'PANTS:',
#   'THE',
#   'DEBATE',
#   'SOMETIMES',
#   'GETS',
#   'VERY',
#   'UGLY'],
#  ['CHEERY,', 'NEWSY', 'MAIL', 'WILL', 'COMFORT', 'AIDS', 'VICTIM'],
#  ['TIME', 'TO', 'BREAK', 'HOLIDAY', 'TRADITION'],
#  ['SHY', 'GUY', 'TOLD:', "DON'T", 'GIVE', 'UP'],
#  ['CHILD', "CAN'T", 'BE', 'SECRET', 'FOREVER'],
#  ["MOTHER'S", 'DAY', 'LEAVES', 'MOM', 'ANGRY'],
#  ['A', 'GIFT', 'FOR', 'DAD', 'FROM', 'THE', 'HEART'],
#  ['JUGGLING', 'CHECKS', 'TOUGH', 'FOR', 'WAITRESS'],
#  ['JILTED', 'COED', 'LEARNS', 'A', 'PAINFUL', 'LESSON'],
#  ['FLOWERS', 'OR', 'A', 'CARD', 'FOR', "PET'S", 'MOURNER'],
#  ['REPAIRMEN', 'PLAY', 'WAITING', 'GAME,', 'TOO'],
#  ['CHILDREN', 'CRUEL', 'WHEN', 'CHOOSING', 'SIDES'],
#  ['SHOULD', 'FRIENDS', 'SHARE', 'HOT', 'TUB?'],
#  ['TWO-WAY', 'SWINGER', 'IS', 'HARD', 'TO', 'SPOT'],
#  ['SHOULD', 'KIDS', 'BE', 'IN', 'A', 'WEDDING?'],
#  ["ABBY'S", 'NEW', 'COOKBOOKLET', 'IS', 'READY!'],
#  ['A', 'CORNY', 'TALE', 'WITH', 'A', 'KERNEL', 'OF', 'TRUTH'],
#  ["IT'S", 'TIME', 'TO', 'FIX', 'THOSE', 'REPAIRMEN', 'WHO', 'NEVER', 'ARRIVE'],
#  ['CHILD-PROOF', 'HOUSE', 'FROM', "TOT'S", 'VIEW'],
#  ["IT'S",
#   'NICE',
#   'TO',
#   'KNOW',
#   'THAT',
#   'THE',
#   'FAMOUS',
#   'CAN',
#   'LOOK',
#   'FOOLISH'],
#  ["CHILD'S", 'CRYING', 'IS', 'MUSIC', 'TO', 'HIS', 'EARS'],
#  ['SOAPS', 'FAN', 'TIRED', 'OF', "'MOM'S'", 'STATIC'],
#  ['INCESSANT', 'TALKER', 'SHOULD', 'OPEN', 'EARS'],
#  ['IN', 'GRIEF,', 'ANY', 'WORDS', 'ARE', 'WELCOME'],
#  ['IN', 'DEFENSE', 'OF', 'BABIES', 'AT', 'WEDDINGS'],
#  ['CHILD', 'GOES', 'OUT', 'OF', 'WAY', 'TO', 'FOIL', 'CRIB'],
#  ['IN',
#   'AGE',
#   'OF',
#   'AIDS,',
#   'A',
#   'KISS',
#   'IS',
#   'STILL',
#   'A',
#   'KISS,',
#   'BUT',
#   '.',
#   '.',
#   '.'],
#  ['RELIEF', 'FOR', "'DRY", "MOUTH'", 'SUFFERERS'],
#  ['DRUGS', 'TINGE', 'SUCCESS', 'STORY'],
#  ['PHOTO', 'FIGHT', 'LEADS', 'TO', 'WAR', 'OF', 'WORDS'],
#  ['DRIVERS', 'CAN', 'BE', 'VICTIMS,', 'TOO'],
#  ['TALE', 'OF', "'TANNING'", 'IS', 'HALF-BAKED'],
#  ['TAKE', 'NO', 'RISKS', 'WITH', 'AIDS'],
#  ['EX-WIFE', 'RESENTS', 'MISTRESS', 'AS', 'GUEST'],
#  ['EXCESSIVE', 'DONATION', 'REQUESTS', 'SPARK', 'UNCHARITABLE', 'FEELINGS'],
#  ['NEIGHBOR', 'WHISTLES', 'WHILE', 'HE', 'WORKS'],
#  ["SON'S", 'VISITS', 'ARE', 'TOO', 'MUCH'],
#  ["WHAT'S", 'IN', 'A', 'NAME', 'CHANGE?', 'A', 'LOT', 'OF', 'EXPLAINING'],
#  ['NO', 'CALIFORNIA', 'DREAM', 'FOR', 'HER'],
#  ['SPELL', 'OUT', 'RULES', 'FOR', 'BABY-SITTER'],
#  ["'FLAWED", "LAW'", 'IS', 'CHANGED', 'BY', 'OUTCRY'],
#  ['NO', 'TRUTH', 'TO', 'VICIOUS', 'P', '&', 'G', 'RUMOR'],
#  ['WHERE', "THERE'S", 'SMOKE', "THERE'S", 'IRE', 'IN', 'THIS', 'FAMILY'],
#  ['NOISY', 'SLEEPING', 'THREATENS', 'MARRIAGE'],
#  ['WHY', 'HAIRSTYLES', 'FOR', 'MILITARY', 'MEN?'],
#  ['OUTRAGE', 'OVER', "STATE'S", "'FLAWED", "LAW'"],
#  ['WIFE', 'DECIDES', 'TO', 'LIVE', 'WITHOUT', 'SEX'],
#  ['GIRL', 'AND', 'STEPDAD', 'WERE', 'TOO', "'CLOSE'"],
#  ['GIRL', 'WANTS', 'TO', 'REGAIN', 'LOST', 'VIRGINITY'],
#  ['GUN', 'CONTROL', 'IS', "PARENTS'", 'JOB'],
#  ["GRANDMOM'S", 'EMPTY', 'CARD', 'IS', 'A', 'FAIR', 'EXCHANGE'],
#  ['WHERE',
#   "THERE'S",
#   'A',
#   'WILL,',
#   "THERE'S",
#   'AN',
#   'EASIER',
#   'TIME',
#   'OF',
#   'IT',
#   'FOR',
#   'A',
#   'WIDOW'],
#  ['PEER', 'PRESSURE', 'CAN', 'HELP', 'SMOKERS'],
#  ["ALCOHOLIC'S", 'PLIGHT', 'UPSETS', 'STRANGER'],
#  ["'SINGLE'", 'LOVER', 'LIVED', 'A', 'DOUBLE', 'LIFE'],
#  ["THERE'S", 'NOTHING', 'SHABBY', 'ABOUT', 'THIS', 'COVER-UP'],
#  ['HUSBAND',
#   'WHO',
#   'SLEEPS',
#   'AROUND',
#   'BUT',
#   'BLAMES',
#   'WIFE',
#   'NEEDS',
#   'HELP',
#   'IN',
#   'GROWING',
#   'UP'],
#  ['THERE', 'ARE', 'STILL', 'CARING', 'PEOPLE'],
#  ['THERAPY', 'HELPS', 'DAUGHTER', 'DEAL', 'WITH', 'MOLESTATION'],
#  ['HUMANS', 'ACT', 'LIKE', 'ANIMALS?', 'NEVER!'],
#  ['SURROGATE', 'MOTHERS', 'MAKE', 'A', 'SAYING', 'COME', 'TRUE'],
#  ['DOUBLE', 'MESSAGE', 'IN', 'MARRIAGE', 'PRIZE'],
#  ['FRIENDS', 'HAVE', 'A', 'FALSE', 'FIXATION'],
#  ['FATHER', 'FRETS', 'OVER', 'CAMPUS', 'MORALS'],
#  ['TEACHER', 'OBJECTS', 'TO', "'NO.", "1'", 'GIFTS'],
#  ['TERRIFIED', 'BY', 'ATTIC', 'SNAKE'],
#  ['HELP', 'IS', 'JUST', 'A', 'PHONE', 'CALL', 'AWAY'],
#  ['PARENTS', 'UPSET', 'BY', 'COLLEGIATE', 'MORALS'],
#  ['AIDS', 'FROM', 'A', 'TATTOO?'],
#  ["DON'T", 'STIFF', 'YOUR', 'PAPER', 'CARRIERS'],
#  ["'TIS", 'THE', 'SEASON', 'FOR', 'RECYCLED', 'GIFTS'],
#  ['HAPPY', 'WIFE', 'GOT', 'HER', 'MAN', 'BY', 'MAIL'],
#  ['WOMAN', 'WITH', '2', 'SUITORS', 'WANTS', 'BOTH!'],
#  ['VALUABLE', 'LESSON', 'FROM', 'RECYCLED', 'GIFT'],
#  ["'FAITHFULS'", 'LEAD', 'THE', 'FIDELITY', 'SURVEY'],
#  ['HERPES', 'VICTIM', 'NOT', 'LAUGHING'],
#  ["'CASH", "SHORTAGE'", 'ENDS', 'FRIENDSHIP'],
#  ['GRADUATION', "'GIFT'", 'FROM', 'DAD', "DOESN'T", 'MAKE', 'THE', 'GRADE'],
#  ['CRIME', 'PREVENTION', 'IS', 'FOR', 'EVERYONE'],
#  ['MILITARY', 'MAN', 'HAS', 'YEN', 'FOR', 'SPANKING'],
#  ['FREE', 'ADVICE?', 'TIME', 'IS', 'ALSO', 'MONEY'],
#  ['MINISTER', 'BERATES', 'GRIEVING', 'HUSBAND'],
#  ['LABEL', 'THOSE', 'PRECIOUS', 'PHOTOS!'],
#  ['PUT', 'ASIDE', 'ANGER', 'OVER', 'INVITATION'],
#  ['BROKEN', 'WEDDING', 'PLANS', 'ARE', 'CHEAP'],
#  ['FORGOTTEN', 'NIGHTIE', 'CAUSES', 'ANGUISH'],
#  ['A', "WIDOW'S", 'PAIN', 'NEVER', 'GOES', 'AWAY'],
#  ['SEX', 'IS', 'MATTER', 'OF', 'PRINCIPLE'],
#  ['POISON', 'FROM', "'HARMLESS'", 'SOURCES'],
#  ['PREJUDICE', 'COULD', 'RUIN', 'A', 'FRIENDSHIP'],
#  ['DEBUNKING', 'MYTHS-NEW', 'AND', 'OLD'],
#  ['SAY', "'NO'", 'UNTIL', 'READY', 'FOR', "'YES'"],
#  ['BIGOTRY', 'SHOULD', 'NEVER', 'BE', 'TOLERATED'],
#  ['FOLLOW', 'RULES', 'OF', 'THE', 'DATING', 'GAME'],
#  ['A',
#   "SIBLING'S",
#   'CRIME',
#   'CAN',
#   'BE',
#   'FORGIVEN',
#   'IF',
#   'NOT',
#   'FORGOTTEN'],
#  ["DOG'S", 'BITE', 'IS', 'WORSE', 'THAN', 'ITS', 'BARK'],
#  ['DAD', 'REFUSES', 'TO', 'PAY', 'TUITION'],
#  ['MAN', 'WANTS', 'TO', 'RE-KINDLE', 'OLD', 'FLAME'],
#  ['A', 'ROMANCE', 'WITH', 'A', 'YOUNGER', 'MAN?'],
#  ['BOUQUETS', 'AND', 'BRICKBATS', 'FOR', 'ABBY'],
#  ['BAD', 'NEWS', "DOESN'T", 'ALWAYS', 'TRAVEL', 'FAST'],
#  ['FREELOADERS', 'ARE', "MOM'S", 'BURDEN'],
#  ['CURRENT',
#   'FLAME',
#   'FINISHES',
#   'SECOND',
#   'IN',
#   'BEDROOM',
#   'PHOTO',
#   'FINISH'],
#  ['DENTAL', 'WORK', 'WORTH', 'BUDGET', 'BITE'],
#  ['KIDS', 'IN', 'THIRD', 'PLACE', 'WITH', 'GRANDMA'],
#  ['MOTHER', "DOESN'T", 'ALWAYS', 'KNOW', 'BEST'],
#  ['BUS', 'DRIVER,', 'RIDER', 'CLASH', 'OVER', 'VIEWS'],
#  ['FREELOADER', 'ANGERS', 'CARD', 'CRONIES'],
#  ['THIEVES:', 'KEEP', 'CASH,', 'RETURN', 'PURSE'],
#  ['THIS', "POEM'S", 'ORIGIN', 'IS', 'WELL', 'RECORDED'],
#  ['THIS', 'PREACHER', 'LIKES', 'CONVERSATION'],
#  ['SMOKERS', 'CHOKE', 'HOLIDAY', 'FESTIVITIES'],
#  ["DON'T", 'SHUT', 'EYES', 'TO', "'PEEPING", "TOM'"],
#  ['SOME', 'RULES', 'FOR', 'HOSPITAL', 'VISITORS'],
#  ['BRANDING', 'AIDS', 'VICTIMS', 'INHUMANE'],
#  ['FOOLISH', 'TO', 'LEAVE', 'A', 'DOOR', 'UNLOCKED'],
#  ['MONEY', 'TIES', 'WIFE', 'TO', 'DULL', 'MARRIAGE'],
#  ['DANCER', 'WALTZES', 'AWAY', 'WITH', 'ESTATE'],
#  ['LIVE-IN', 'MAY', 'HAVE', 'TO', 'SPEND', 'TIME', 'TO', 'EARN', 'FRIENDS'],
#  ['TICKLING', 'IS', 'NO', 'LAUGHING', 'MATTER'],
#  ['ORCHARD', 'VENTURE', 'FAILS', 'TO', 'BEAR', 'FRUIT'],
#  ["'THANK", "YOU'", 'NOTE', 'A', 'MUST'],
#  ['SKELETONS', 'FROM', "HUSBAND'S", 'CLOSET', 'STILL', 'RATTLE', 'WIDOW'],
#  ['POST-HOLIDAY', 'CHRISTMAS', 'CARD', 'CHEER'],
#  ['DIETERS', 'LOOK', 'FOR', 'DIVINE', 'INSPIRATION'],
#  ["MAN'S", 'FAMILY', 'SHUTS', 'OUT', 'NEW', 'WIFE'],
#  ["DAD'S", 'WEDDING', 'ROLE', 'ANGERS', 'FIANCE'],
#  ['WILL', 'HEAVEN', 'BE', 'CLOUD', '9--OR', 'UNHAPPY', 'REUNION?'],
#  ['MOM', 'CARRIES', 'ON', 'TRADITION', 'OF', 'ABUSE'],
#  ['AN', 'AFFAIR', 'FOR', 'SEX?', 'FORGET', 'IT!'],
#  ['THE', 'NEW', 'HOLIDAY', 'PLATE', 'TURNS', 'OUT', 'TO', 'BE', 'PAPER'],
#  ['SOMETHING', 'OLD', 'FOR', 'BRIDESMAIDS?'],
#  ['HUNG', 'UP', 'ON', 'MAN', 'SHE', 'NEVER', 'MET'],
#  ['TEEN', 'RESENTS', "GRANDPA'S", "'FRIEND'"],
#  ['CAN', 'LOVE', 'CONQUER', 'GROSS', 'MANNERS?'],
#  ['DAD', 'WANTS', 'TO', "'BUTCH", "UP'", 'HIS', 'SON'],
#  ['WOMAN',
#   'IN',
#   'HOPELESS',
#   'TRIANGLE',
#   'WITH',
#   'MARRIED',
#   'MAN',
#   'SHOULD',
#   'REASSESS',
#   'SITUATION'],
#  ["'SAFE", "SEX'", 'RAISES', 'A', 'QUESTION'],
#  ['HUSBAND', 'SHOULD', 'END', 'DOUBLE', 'LIFE'],
#  ['CONTACTING', 'OLD', 'FLAME', 'COULD', 'BURN'],
#  ['SOME', 'THINGS', 'STRETCH', 'LIMITS', 'OF', 'FRIENDSHIP'],
#  ['BOWLEGGED', 'WOMAN', 'STICKS', 'TO', 'PANTS'],
#  ["HUSBAND'S", 'LYING', 'WAYS', 'WILL', 'BE', 'HARD', 'TO', 'CHANGE'],
#  ["DON'T", 'ASK', 'HELP', 'OF', 'OFF-DUTY', 'COP'],
#  ['A', "MOTHER-IN-LAW'S", 'PRAYER:', 'SILENCE'],
#  ['LUPUS', 'DRIVES', 'MOM', 'CLOSE', 'TO', 'EDGE'],
#  ['THE', 'LADY', 'JUST', 'WANTS', 'SLACKS', 'THAT', 'FIT!'],
#  ['FLYING', 'ON', 'THE', 'WINGS', 'OF', 'LOVE', 'IS', 'EXPENSIVE'],
#  ['THE', 'GOSPEL', 'ON', 'DROP-IN', 'MINISTERS'],
#  ['BE', 'WARY', 'OF', 'SECRETIVE', 'HAIRDRESSER'],
#  ['KEEP', 'YOUR', 'ALMA', 'MATERS', 'INFORMED'],
#  ['CHEER', 'WELCOME', 'AT', 'NURSING', 'HOMES'],
#  ['BOTH', 'GIRLFRIEND,', 'WIFE', 'ARE', 'EXPECTING'],
#  ['ANGER', 'AT', 'THE', "'OTHER", "WOMAN'", 'COULD', 'HURT', 'A', 'PAL'],
#  ['WIFE', 'BLACKMAILED', 'FOR', 'MARITAL', 'LAPSE'],
#  ...]

# %%
num_topics = 8

# %%
id2word = gensim.corpora.Dictionary(titles)
corpus = [id2word.doc2bow(text) for text in titles]

lda = ldamodel.LdaModel(corpus=corpus, 
                        id2word=id2word, 
                        num_topics=num_topics)
lsi = LsiModel(corpus=corpus, 
               num_topics=num_topics, 
               id2word=id2word)

# %%
def get_topics(model = lda, num_topics =num_topics):
    word_dict = {}
    for i in range(num_topics):
        words = model.show_topic(i, topn=12392)
        word_dict['Topic #'+'{:02d}'.format(i+1)] = [i[0] for i in words]
    return pd.DataFrame(word_dict,data_total[['title']])

# %%
topics = pd.DataFrame(get_topics())

topics_1 = pd.DataFrame(get_topics(model=lsi))

# %%
display(topics.head(4))
# Out:
#                                                    Topic #01 Topic #02  \
# (A POINTED REMINDER ABOUT HOW CROWDED IT'S GETT...      More       May
# (AMERICAN SMOKEOUT DAY CHANCE TO SNUFF OUT HABIT,)     Dad's       Dad
# (HOW DID 'PEGGY' BECOME A NICKNAME FOR 'MARGARE...   Grandma    Sister
# (HUSBAND CAN'T STOMACH WIFE'S VOW TO DONATE ORG...    Return        To
#
#                                                    Topic #03 Topic #04  \
# (A POINTED REMINDER ABOUT HOW CROWDED IT'S GETT...        Is        Is
# (AMERICAN SMOKEOUT DAY CHANCE TO SNUFF OUT HABIT,)       Mom    Family
# (HOW DID 'PEGGY' BECOME A NICKNAME FOR 'MARGARE...      With   Husband
# (HUSBAND CAN'T STOMACH WIFE'S VOW TO DONATE ORG...       Her      Wife
#
#                                                    Topic #05 Topic #06  \
# (A POINTED REMINDER ABOUT HOW CROWDED IT'S GETT...   Wedding
# (AMERICAN SMOKEOUT DAY CHANCE TO SNUFF OUT HABIT,)     Wants       For
# (HOW DID 'PEGGY' BECOME A NICKNAME FOR 'MARGARE...        On        Is
# (HUSBAND CAN'T STOMACH WIFE'S VOW TO DONATE ORG...    Leaves      Help
#
#                                                    Topic #07  Topic #08
# (A POINTED REMINDER ABOUT HOW CROWDED IT'S GETT...     After     Friend
# (AMERICAN SMOKEOUT DAY CHANCE TO SNUFF OUT HABIT,)      Home  Husband's
# (HOW DID 'PEGGY' BECOME A NICKNAME FOR 'MARGARE...      Will         Of
# (HUSBAND CAN'T STOMACH WIFE'S VOW TO DONATE ORG...      Gets         In

# %%
display(topics_1.head(4))
# Out:
#                                                    Topic #01 Topic #02  \
# (A POINTED REMINDER ABOUT HOW CROWDED IT'S GETT...        Is        Is
# (AMERICAN SMOKEOUT DAY CHANCE TO SNUFF OUT HABIT,)       Her       Her
# (HOW DID 'PEGGY' BECOME A NICKNAME FOR 'MARGARE...      With      With
# (HUSBAND CAN'T STOMACH WIFE'S VOW TO DONATE ORG...      Wife     Woman
#
#                                                    Topic #03 Topic #04  \
# (A POINTED REMINDER ABOUT HOW CROWDED IT'S GETT...         A       Her
# (AMERICAN SMOKEOUT DAY CHANCE TO SNUFF OUT HABIT,)        TO      Wife
# (HOW DID 'PEGGY' BECOME A NICKNAME FOR 'MARGARE...        OF      With
# (HUSBAND CAN'T STOMACH WIFE'S VOW TO DONATE ORG...       FOR       His
#
#                                                    Topic #05 Topic #06  \
# (A POINTED REMINDER ABOUT HOW CROWDED IT'S GETT...      With     Woman
# (AMERICAN SMOKEOUT DAY CHANCE TO SNUFF OUT HABIT,)      Wife       Mom
# (HOW DID 'PEGGY' BECOME A NICKNAME FOR 'MARGARE...     Woman      With
# (HUSBAND CAN'T STOMACH WIFE'S VOW TO DONATE ORG...       Her       Man
#
#                                                    Topic #07 Topic #08
# (A POINTED REMINDER ABOUT HOW CROWDED IT'S GETT...
# (AMERICAN SMOKEOUT DAY CHANCE TO SNUFF OUT HABIT,)      With      With
# (HOW DID 'PEGGY' BECOME A NICKNAME FOR 'MARGARE...       Mom        Be
# (HUSBAND CAN'T STOMACH WIFE'S VOW TO DONATE ORG...        Be      Wife

# %%
lsi_topics = lsi.show_topics(num_topics=num_topics, formatted=False)

display(lsi_topics)
# Out:
# [(0,
#   [('Is', -0.8093704576773872),
#    ('Her', -0.22419011523203447),
#    ('With', -0.19319732554477664),
#    ('Wife', -0.16161221104176482),
#    ('Woman', -0.14825929963921014),
#    ('Mom', -0.12333710897430152),
#    ('Man', -0.12230557461238145),
#    ('His', -0.1108095934141122),
#    ('Husband', -0.09151112632991577),
#    ('To', -0.09088772376266073)]),
#  (1,
#   [('Is', 0.5395498587339791),
#    ('Her', -0.5062516981204075),
#    ('With', -0.33882691975262713),
#    ('Woman', -0.25303327508109247),
#    ('Wife', -0.21640902807264303),
#    ('Mom', -0.16889128794996375),
#    ('Man', -0.154403164772361),
#    ('His', -0.11878784947789511),
#    ('Husband', -0.11171353497580917),
#    ('Who', -0.10895548603065583)]),
#  (2,
#   [('A', -0.9014315463924958),
#    ('TO', -0.21840769554297954),
#    ('OF', -0.13752210425933517),
#    ('FOR', -0.12521042996781206),
#    ('THE', -0.12005207411618979),
#    ('Her', 0.11579410322968775),
#    ('To', -0.104749475828675),
#    ('BE', -0.08218643923101387),
#    ('Is', 0.08079628338910155),
#    ('IN', -0.0788321559891998)]),
#  (3,
#   [('Her', -0.6403014603459716),
#    ('Wife', 0.4316179078295772),
#    ('With', 0.340912913225898),
#    ('His', 0.28509969345166863),
#    ('Man', 0.24258564606355296),
#    ('Husband', 0.18552868106354276),
#    ('Mom', -0.1429065442165904),
#    ('Woman', -0.1381247620731658),
#    ("Husband's", 0.091076545364367),
#    ('A', -0.08693548330583914)]),
#  (4,
#   [('With', -0.6343814850276718),
#    ('Wife', 0.5642371916093729),
#    ('Woman', -0.2645301183689091),
#    ('Her', 0.25939894696635013),
#    ('Husband', 0.23954586363154354),
#    ('His', 0.1714072737393572),
#    ("Husband's", 0.12108718935245322),
#    ('Mom', -0.06338686853647743),
#    ('Be', -0.05378178673180615),
#    ('Family', -0.03884863482700941)]),
#  (5,
#   [('Woman', -0.6790721199274927),
#    ('Mom', 0.5592967922673353),
#    ('With', 0.2466518137501704),
#    ('Man', -0.20973663298832398),
#    ('Daughter', 0.19425244848977266),
#    ('', -0.14401886050875978),
#    ('Who', -0.1074325170982121),
#    ('Son', 0.0744507403998709),
#    ("Daughter's", 0.053919323770877076),
#    ('Dad', 0.051870980843686604)]),
#  (6,
#   [('', -0.8102871359565389),
#    ('With', 0.2543455176224852),
#    ('Mom', -0.2214904385287199),
#    ('Be', -0.19450490756089747),
#    ('To', -0.17661406718204778),
#    ('Wife', 0.14839560723698617),
#    ('Her', 0.12130696160459338),
#    ('Family', -0.11228654350318337),
#    ('From', -0.08952191022673592),
#    ('Husband', 0.08405555370169035)]),
#  (7,
#   [('', -0.5420293948996436),
#    ('With', -0.38563294771747747),
#    ('Be', 0.33241978507011105),
#    ('Wife', -0.21462124722836745),
#    ('Her', -0.2139511499476705),
#    ('Man', 0.21284095478898876),
#    ('Mom', 0.2031323423952309),
#    ('His', 0.19615752326921523),
#    ('Family', 0.16527991234981862),
#    ('To', 0.14794886185022285)])]
